# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import os
import time
import psutil
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import LabelEncoder
from codecarbon import EmissionsTracker

# %% [markdown]
# # **Directorio para resultados**

# %%
result_path = "results"
os.makedirs(result_path, exist_ok=True)
os.makedirs(f"{result_path}/emissions_reports", exist_ok=True)
os.makedirs(f"{result_path}/emissions_plots", exist_ok=True)

# %% [markdown]
# # **Parámetros de entrenamiento**

# %%
config = {
    'embedding_dim': 128,
    'hidden_dim': 128,
    'batch_size': 1024,
    'learning_rate': 1e-3,
    'epochs': 50,
    'display_step': 1,
    'test_size': 0.2,
    'random_state': 42
}

# %% [markdown]
# # **Clase para el seguimiento de métricas del sistema**

# %%
class SystemMetricsTracker:
    def __init__(self):
        self.train_metrics = []
        self.test_metrics = {}
        self.start_time = time.time()
        
    def start_epoch(self, epoch):
        self.epoch_start_time = time.time()
        self.current_epoch_metrics = {
            'epoch': epoch,
            'memory_usage_mb': psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2,
            'cpu_usage_percent': psutil.cpu_percent(),
        }
        
    def end_epoch(self, epoch, loss, rmse=None, mae=None):
        epoch_time = time.time() - self.epoch_start_time
        self.current_epoch_metrics['epoch_time_sec'] = epoch_time
        self.current_epoch_metrics['loss'] = loss
        if rmse is not None:
            self.current_epoch_metrics['rmse'] = rmse
        if mae is not None:
            self.current_epoch_metrics['mae'] = mae
        self.train_metrics.append(self.current_epoch_metrics)
        
        # Imprimir resumen de época
        print(f"\nEpoch {epoch} Metrics:")
        print(f"  Time: {epoch_time:.2f}s")
        print(f"  Memory: {self.current_epoch_metrics['memory_usage_mb']:.2f}MB")
        print(f"  CPU: {self.current_epoch_metrics['cpu_usage_percent']:.1f}%")
        print(f"  Loss: {loss:.4f}")
        if rmse is not None:
            print(f"  RMSE: {rmse:.4f}")
        if mae is not None:
            print(f"  MAE: {mae:.4f}")
        
    def end_test(self, rmse, mae=None):
        self.test_metrics = {
            'test_time_sec': time.time() - self.epoch_start_time,
            'total_time_sec': time.time() - self.start_time,
            'final_memory_usage_mb': psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2,
            'final_cpu_usage_percent': psutil.cpu_percent(),
            'test_rmse': rmse,
        }
        if mae is not None:
            self.test_metrics['test_mae'] = mae
        
        # Imprimir métricas finales
        print("\n=== Final Training Metrics ===")
        for m in self.train_metrics:
            metrics_str = f"Epoch {m['epoch']}: Time={m['epoch_time_sec']:.2f}s, Memory={m['memory_usage_mb']:.2f}MB, CPU={m['cpu_usage_percent']:.1f}%, Loss={m['loss']:.4f}"
            if 'rmse' in m:
                metrics_str += f", RMSE={m['rmse']:.4f}"
            if 'mae' in m:
                metrics_str += f", MAE={m['mae']:.4f}"
            print(metrics_str)
        
        print("\n=== Final Test Metrics ===")
        print(f"Total Time: {self.test_metrics['total_time_sec']:.2f}s (Test: {self.test_metrics['test_time_sec']:.2f}s)")
        print(f"Final Memory: {self.test_metrics['final_memory_usage_mb']:.2f}MB")
        print(f"Final CPU: {self.test_metrics['final_cpu_usage_percent']:.1f}%")
        print(f"Test RMSE: {rmse:.4f}")
        if mae is not None:
            print(f"Test MAE: {mae:.4f}")
        
        # Guardar métricas en CSV
        timestamp = time.strftime("%Y%m%d-%H%M%S")
        metrics_df = pd.DataFrame(self.train_metrics)
        metrics_df.to_csv(f"{result_path}/system_metrics_{timestamp}.csv", index=False)

# %% [markdown]
# # **Clase para seguimiento de emisiones por época**

# %%
class EmissionsPerEpochTracker:
    def __init__(self, result_path, model_name="NCF"):
        self.result_path = result_path
        self.model_name = model_name
        self.epoch_emissions = []
        self.cumulative_emissions = []
        self.epoch_rmse = []
        self.epoch_mae = []
        self.epoch_loss = []
        self.total_emissions = 0.0
        self.trackers = {}
        
        # Inicializar tracker principal
        self.main_tracker = EmissionsTracker(
            project_name=f"{model_name}_total",
            output_dir=f"{result_path}/emissions_reports",
            save_to_file=True,
            log_level="error",
            save_to_api=False,
            tracking_mode="process"
        )
        try:
            self.main_tracker.start()
            print("Tracker principal iniciado correctamente")
        except Exception as e:
            print(f"Advertencia: No se pudo iniciar el tracker principal: {e}")
            self.main_tracker = None
    
    def start_epoch(self, epoch):
        # Crear un tracker con un nombre único basado en timestamp
        timestamp = int(time.time())
        tracker_name = f"{self.model_name}_epoch{epoch}_{timestamp}"
        
        self.trackers[epoch] = EmissionsTracker(
            project_name=tracker_name,
            output_dir=f"{self.result_path}/emissions_reports",
            save_to_file=True,
            log_level="error",
            save_to_api=False,
            tracking_mode="process",
            measure_power_secs=1,
            allow_multiple_runs=True
        )
        try:
            self.trackers[epoch].start()
        except Exception as e:
            print(f"Advertencia: No se pudo iniciar el tracker para la época {epoch}: {e}")
            self.trackers[epoch] = None
    
    def end_epoch(self, epoch, loss, rmse=None, mae=None):
        try:
            epoch_co2 = 0.0
            if epoch in self.trackers and self.trackers[epoch]:
                try:
                    epoch_co2 = self.trackers[epoch].stop() or 0.0
                except Exception as e:
                    print(f"Advertencia: Error al detener el tracker para la época {epoch}: {e}")
                    epoch_co2 = 0.0
            
            # Acumular emisiones totales
            self.total_emissions += epoch_co2
            
            # Guardar datos de esta época
            self.epoch_emissions.append(epoch_co2)
            self.cumulative_emissions.append(self.total_emissions)
            self.epoch_loss.append(loss)
            if rmse is not None:
                self.epoch_rmse.append(rmse)
            if mae is not None:
                self.epoch_mae.append(mae)
            
            print(f"Epoch {epoch} - Emisiones: {epoch_co2:.8f} kg, Acumulado: {self.total_emissions:.8f} kg, Loss: {loss:.4f}")
            if rmse is not None:
                print(f"RMSE: {rmse:.4f}")
            if mae is not None:
                print(f"MAE: {mae:.4f}")
        except Exception as e:
            print(f"Error al medir emisiones en época {epoch}: {e}")
    
    def end_training(self, final_rmse, final_mae=None):
        try:
            # Detener el tracker principal
            final_emissions = 0.0
            if hasattr(self, 'main_tracker') and self.main_tracker:
                try:
                    final_emissions = self.main_tracker.stop() or 0.0
                    print(f"\nTotal CO2 Emissions: {final_emissions:.6f} kg")
                except Exception as e:
                    print(f"Error al detener el tracker principal: {e}")
                    final_emissions = self.total_emissions
            else:
                final_emissions = self.total_emissions
            
            # Asegurarse de que todos los trackers estén detenidos
            for epoch, tracker in self.trackers.items():
                if tracker is not None:
                    try:
                        tracker.stop()
                    except:
                        pass
            
            # Si no hay datos de emisiones por época pero tenemos emisiones totales,
            # crear al menos una entrada para gráficos
            if not self.epoch_emissions and final_emissions > 0:
                self.epoch_emissions = [final_emissions]
                self.cumulative_emissions = [final_emissions]
                if final_rmse is not None:
                    self.epoch_rmse = [final_rmse]
                if final_mae is not None:
                    self.epoch_mae = [final_mae]
            
            # Si no hay datos, salir
            if not self.epoch_emissions:
                print("No hay datos de emisiones para graficar")
                return
            
            # Asegurarse de que tengamos un RMSE final si no se rastreó por época
            if not self.epoch_rmse and final_rmse is not None:
                self.epoch_rmse = [final_rmse] * len(self.epoch_emissions)
            
            # Crear dataframe con todos los datos
            timestamp = time.strftime("%Y%m%d-%H%M%S")
            df = pd.DataFrame({
                'epoch': range(len(self.epoch_emissions)),
                'epoch_emissions_kg': self.epoch_emissions,
                'cumulative_emissions_kg': self.cumulative_emissions,
                'loss': self.epoch_loss if self.epoch_loss else [0.0] * len(self.epoch_emissions),
                'rmse': self.epoch_rmse if self.epoch_rmse else [None] * len(self.epoch_emissions),
                'mae': self.epoch_mae if self.epoch_mae else [None] * len(self.epoch_emissions)
            })
            
            emissions_file = f'{self.result_path}/emissions_reports/emissions_metrics_{self.model_name}_{timestamp}.csv'
            df.to_csv(emissions_file, index=False)
            print(f"Métricas de emisiones guardadas en: {emissions_file}")
            
            # Graficar las relaciones
            self.plot_emissions_vs_metrics(timestamp, final_rmse, final_mae)
            
        except Exception as e:
            print(f"Error al generar gráficos de emisiones: {e}")
            import traceback
            traceback.print_exc()
    
    def plot_emissions_vs_metrics(self, timestamp, final_rmse=None, final_mae=None):
        """Genera gráficos para emisiones vs métricas"""
        
        # Configurar estilo para fondo blanco y texto negro (más legible)
        plt.style.use('default')
        
        # Usar RMSE por época si está disponible, sino crear lista con el RMSE final
        if not self.epoch_rmse and final_rmse is not None:
            self.epoch_rmse = [final_rmse] * len(self.epoch_emissions)
        
        try:
            if self.epoch_rmse:
                # 1. Emisiones acumulativas vs RMSE
                plt.figure(figsize=(10, 6), facecolor='white')
                plt.plot(self.cumulative_emissions, self.epoch_rmse, 'b-', marker='o')
                
                # Añadir etiquetas con el número de época
                for i, (emissions, rmse) in enumerate(zip(self.cumulative_emissions, self.epoch_rmse)):
                    plt.annotate(f"{i}", (emissions, rmse), textcoords="offset points", 
                                xytext=(0,10), ha='center', fontsize=9, color='black')
                    
                plt.xlabel('Emisiones de CO2 acumuladas (kg)', color='black')
                plt.ylabel('RMSE', color='black')
                plt.title('Relación entre Emisiones Acumuladas y RMSE', color='black')
                plt.grid(True, alpha=0.3)
                plt.tick_params(colors='black')
                
                file_path = f'{self.result_path}/emissions_plots/cumulative_emissions_vs_rmse_{self.model_name}_{timestamp}.png'
                plt.savefig(file_path, facecolor='white')
                plt.close()
                print(f"Gráfico guardado en: {file_path}")
            
            # 2. Gráfico combinado: Emisiones por época y acumulativas
            plt.figure(figsize=(12, 10), facecolor='white')
            
            plt.subplot(2, 2, 1)
            plt.plot(range(len(self.epoch_emissions)), self.epoch_emissions, 'r-', marker='x')
            plt.title('Emisiones por Época', color='black')
            plt.xlabel('Época', color='black')
            plt.ylabel('CO2 Emissions (kg)', color='black')
            plt.tick_params(colors='black')
            
            plt.subplot(2, 2, 2)
            plt.plot(range(len(self.cumulative_emissions)), self.cumulative_emissions, 'r-', marker='o')
            plt.title('Emisiones Acumuladas por Época', color='black')
            plt.xlabel('Época', color='black')
            plt.ylabel('CO2 Emissions (kg)', color='black')
            plt.tick_params(colors='black')
            
            if self.epoch_loss:
                plt.subplot(2, 2, 3)
                plt.plot(range(len(self.epoch_loss)), self.epoch_loss, 'g-', marker='o')
                plt.title('Loss por Época', color='black')
                plt.xlabel('Época', color='black')
                plt.ylabel('Loss', color='black')
                plt.tick_params(colors='black')
            
            if self.epoch_rmse:
                plt.subplot(2, 2, 4)
                plt.plot(range(len(self.epoch_rmse)), self.epoch_rmse, 'b-', marker='o')
                plt.title('RMSE por Época', color='black')
                plt.xlabel('Época', color='black')
                plt.ylabel('RMSE', color='black')
                plt.tick_params(colors='black')
            
            plt.tight_layout()
            
            file_path = f'{self.result_path}/emissions_plots/metrics_by_epoch_{self.model_name}_{timestamp}.png'
            plt.savefig(file_path, facecolor='white')
            plt.close()
            print(f"Gráfico guardado en: {file_path}")
            
            if self.epoch_rmse:
                # 3. Scatter plot de rendimiento frente a emisiones acumulativas
                plt.figure(figsize=(10, 6), facecolor='white')
                
                # Ajustar tamaño de los puntos según la época
                sizes = [(i+1)*20 for i in range(len(self.cumulative_emissions))]
                
                scatter = plt.scatter(self.epoch_rmse, self.cumulative_emissions, 
                            color='blue', marker='o', s=sizes, alpha=0.7)
                
                # Añadir etiquetas de época
                for i, (rmse, em) in enumerate(zip(self.epoch_rmse, self.cumulative_emissions)):
                    plt.annotate(f"{i}", (rmse, em), textcoords="offset points", 
                                xytext=(0,5), ha='center', fontsize=9, color='black')
                
                plt.ylabel('Emisiones de CO2 acumuladas (kg)', color='black')
                plt.xlabel('RMSE', color='black')
                plt.title('Relación entre RMSE y Emisiones Acumuladas', color='black')
                plt.grid(True, alpha=0.3)
                plt.tick_params(colors='black')
                
                file_path = f'{self.result_path}/emissions_plots/cumulative_emissions_performance_scatter_{self.model_name}_{timestamp}.png'
                plt.savefig(file_path, facecolor='white')
                plt.close()
                print(f"Gráfico guardado en: {file_path}")
                
            # 4. Si tenemos RMSE y MAE, crear un gráfico comparativo
            if self.epoch_mae and self.epoch_rmse:
                plt.figure(figsize=(10, 6), facecolor='white')
                plt.plot(range(len(self.epoch_rmse)), self.epoch_rmse, 'b-', marker='o', label='RMSE')
                plt.plot(range(len(self.epoch_mae)), self.epoch_mae, 'g-', marker='s', label='MAE')
                plt.title('Comparación de RMSE y MAE por Época', color='black')
                plt.xlabel('Época', color='black')
                plt.ylabel('Error', color='black')
                plt.legend()
                plt.grid(True, alpha=0.3)
                plt.tick_params(colors='black')
                
                file_path = f'{self.result_path}/emissions_plots/rmse_vs_mae_{self.model_name}_{timestamp}.png'
                plt.savefig(file_path, facecolor='white')
                plt.close()
                print(f"Gráfico comparativo guardado en: {file_path}")
                
        except Exception as e:
            print(f"Error al generar los gráficos: {e}")
            import traceback
            traceback.print_exc()

# %% [markdown]
# # **Cargar el dataset**

# %%
# Load MovieLens dataset
movies_df = pd.read_csv('C://Users//xpati//Documents//TFG//ml-1m//movies.dat', 
                       sep='::', 
                       header=None, 
                       names=['movieId', 'title', 'genres'],
                       encoding='latin-1',
                       engine='python')

ratings_df = pd.read_csv('C://Users//xpati//Documents//TFG//ml-1m//ratings.dat', 
                        sep='::', 
                        header=None, 
                        names=['userId', 'movieId', 'rating', 'timestamp'],
                        encoding='latin-1',
                        engine='python')

# Display first few rows
print(movies_df.head())
print(ratings_df.head())
# Out:
#    movieId                               title                        genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy
#    userId  movieId  rating  timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
# Label encoding of user and movie IDs
user_encoder = LabelEncoder()
movie_encoder = LabelEncoder()

ratings_df['userId'] = user_encoder.fit_transform(ratings_df['userId'])
ratings_df['movieId'] = movie_encoder.fit_transform(ratings_df['movieId'])

# Obtener número de usuarios y películas únicas
n_users = len(user_encoder.classes_)
n_movies = len(movie_encoder.classes_)

print(f'Number of users: {n_users}')
print(f'Number of movies: {n_movies}')
# Out:
# Number of users: 6040
# Number of movies: 3706

# %%
class MovieLensDataset(Dataset):
    def __init__(self, ratings_df):
        self.users = ratings_df['userId'].values
        self.movies = ratings_df['movieId'].values
        self.ratings = ratings_df['rating'].values

    def __len__(self):
        return len(self.ratings)

    def __getitem__(self, idx):
        return torch.tensor(self.users[idx], dtype=torch.long), \
               torch.tensor(self.movies[idx], dtype=torch.long), \
               torch.tensor(self.ratings[idx], dtype=torch.float32)

# %% [markdown]
# # ***NCF (Neural Collaborative Filtering) Recommender***

# %%
class NeuralCollaborativeFiltering(nn.Module):
    def __init__(self, n_users, n_movies, embedding_dim=50, hidden_dim=128):
        super(NeuralCollaborativeFiltering, self).__init__()
        
        # Embedding layers for users and movies
        self.user_embedding = nn.Embedding(n_users, embedding_dim)
        self.movie_embedding = nn.Embedding(n_movies, embedding_dim)
        
        # MLP layers for neural network
        self.mlp = nn.Sequential(
            nn.Linear(embedding_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)
        )

    def forward(self, user, movie):
        # Get embeddings
        user_embedded = self.user_embedding(user)
        movie_embedded = self.movie_embedding(movie)
        
        # Concatenate embeddings
        x = torch.cat([user_embedded, movie_embedded], dim=1)
        
        # Pass through MLP
        return self.mlp(x).squeeze()

# %% [markdown]
# # **Entrenamiento y Evaluación**

# %%
def calculate_metrics(model, loader):
    model.eval()
    total_loss = 0
    total_squared_error = 0
    total_absolute_error = 0
    total_samples = 0
    
    with torch.no_grad():
        for user, movie, rating in loader:
            output = model(user, movie)
            loss = criterion(output, rating)
            total_loss += loss.item() * len(rating)
            
            # Calculate squared error and absolute error
            squared_error = (output - rating) ** 2
            absolute_error = torch.abs(output - rating)
            
            # Accumulate total errors
            total_squared_error += squared_error.sum().item()
            total_absolute_error += absolute_error.sum().item()
            total_samples += len(rating)
    
    # Compute metrics
    avg_loss = total_loss / total_samples
    rmse = np.sqrt(total_squared_error / total_samples)
    mae = total_absolute_error / total_samples
    
    return avg_loss, rmse, mae

def train_model():
    # Inicializar trackers
    print("Inicializando trackers...")
    system_tracker = SystemMetricsTracker()
    emissions_tracker = EmissionsPerEpochTracker(result_path, "NCF")
    
    # Inicializar listas para seguimiento de métricas
    train_losses = []
    val_losses = []
    val_rmses = []
    val_maes = []
    
    # Guardar tiempo de inicio para medir tiempo total
    tiempo_inicio = time.time()
    
    # Training loop
    print(f"\nComenzando entrenamiento ({config['epochs']} épocas)...")
    for epoch in range(config['epochs']):
        # Iniciar seguimiento de época
        system_tracker.start_epoch(epoch)
        emissions_tracker.start_epoch(epoch)
        
        # Cambiar a modo de entrenamiento
        model.train()
        total_loss = 0
        total_samples = 0
        
        for user, movie, rating in train_loader:
            # Zero gradients
            optimizer.zero_grad()
            
            # Forward pass
            output = model(user, movie)
            
            # Compute loss
            loss = criterion(output, rating)
            
            # Backward pass and optimization
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item() * len(rating)
            total_samples += len(rating)
        
        # Calcular loss promedio de esta época
        avg_train_loss = total_loss / total_samples
        train_losses.append(avg_train_loss)
        
        # Evaluar en conjunto de validación
        val_loss, val_rmse, val_mae = calculate_metrics(model, val_loader)
        val_losses.append(val_loss)
        val_rmses.append(val_rmse)
        val_maes.append(val_mae)
        
        # Actualizar trackers
        system_tracker.end_epoch(epoch, avg_train_loss, val_rmse, val_mae)
        emissions_tracker.end_epoch(epoch, avg_train_loss, val_rmse, val_mae)
        
        # Mostrar progreso
        if (epoch + 1) % config['display_step'] == 0:
            print(f"Epoch {epoch + 1}/{config['epochs']}, Training Loss: {avg_train_loss:.4f}, Validation RMSE: {val_rmse:.4f}, Validation MAE: {val_mae:.4f}")
    
    print("\nEvaluando modelo en conjunto de prueba final...")
    system_tracker.start_epoch("test")
    
    # Evaluación final
    final_loss, final_rmse, final_mae = calculate_metrics(model, val_loader)
    
    # Finalizar seguimiento - Asegurarnos que esto se ejecute sin excepciones
    metrics_displayed = False
    
    try:
        print("\nGenerando métricas finales del sistema con SystemMetricsTracker...")
        system_tracker.end_test(final_rmse, final_mae)
        metrics_displayed = True
    except Exception as e:
        print(f"Error al generar métricas finales con tracker: {e}")
        import traceback
        traceback.print_exc()
    
    try:
        print("\nGenerando gráficos y métricas de emisiones...")
        emissions_tracker.end_training(final_rmse, final_mae)
    except Exception as e:
        print(f"Error al generar métricas de emisiones: {e}")
        import traceback
        traceback.print_exc()
    
    # Guardar métricas de entrenamiento
    timestamp = time.strftime("%Y%m%d-%H%M%S")
    metrics_df = pd.DataFrame({
        'epoch': list(range(config['epochs'])),
        'train_loss': train_losses,
        'val_loss': val_losses,
        'val_rmse': val_rmses,
        'val_mae': val_maes
    })
    
    metrics_file = f"{result_path}/model_metrics_{timestamp}.csv"
    metrics_df.to_csv(metrics_file, index=False)
    print(f"Métricas del modelo guardadas en: {metrics_file}")
    
    # Siempre mostrar las métricas finales, incluso si los otros métodos fallaron
    print("\n" + "="*60)
    print("MÉTRICAS FINALES DEL SISTEMA (MEDICIÓN INDEPENDIENTE GARANTIZADA)")
    print("="*60)
    
    # Mediciones directas
    memoria_final = psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2
    cpu_final = psutil.cpu_percent(interval=1.0)  # Medición de 1 segundo
    tiempo_total = time.time() - tiempo_inicio
    
    print(f"Memoria final: {memoria_final:.2f} MB")
    print(f"CPU final: {cpu_final:.2f}%")
    print(f"Tiempo total de ejecución: {tiempo_total:.2f} segundos")
    print(f"RMSE final: {final_rmse:.4f}")
    print(f"MAE final: {final_mae:.4f}")
    print("="*60)
    
    # Guardar las métricas finales en un archivo separado para asegurar que se capturen
    final_metrics = {
        'final_memory_mb': memoria_final,
        'final_cpu_percent': cpu_final,
        'total_time_sec': tiempo_total,
        'final_rmse': final_rmse,
        'final_mae': final_mae,
        'timestamp': timestamp
    }
    
    final_metrics_df = pd.DataFrame([final_metrics])
    final_metrics_file = f"{result_path}/final_metrics_{timestamp}.csv"
    final_metrics_df.to_csv(final_metrics_file, index=False)
    print(f"Métricas finales guardadas en: {final_metrics_file}")
    
    print(f"\nEntrenamiento finalizado!")
    print(f"Métricas finales - RMSE: {final_rmse:.4f}, MAE: {final_mae:.4f}")
    
    return final_rmse, final_mae

# Preparar los datos
print("\nPreparando los datasets...")
train_df, val_df = train_test_split(ratings_df, test_size=config['test_size'], random_state=config['random_state'])

# Crear datasets y dataloaders
train_dataset = MovieLensDataset(train_df)
val_dataset = MovieLensDataset(val_df)

train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False)

print(f"Datos preparados: {len(train_df)} muestras de entrenamiento, {len(val_df)} muestras de validación")


# Inicializar modelo, función de pérdida y optimizador
model = NeuralCollaborativeFiltering(n_users, n_movies, 
                                   embedding_dim=config['embedding_dim'], 
                                   hidden_dim=config['hidden_dim'])

criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])

# Ejecutar entrenamiento
final_rmse, final_mae = train_model()

print("Programa finalizado correctamente.")
# Out:
# Preparando los datasets...
# Datos preparados: 800167 muestras de entrenamiento, 200042 muestras de validación
# Inicializando trackers...
# Tracker principal iniciado correctamente
#
# Comenzando entrenamiento (50 épocas)...
#
# Epoch 0 Metrics:
#   Time: 35.85s
#   Memory: 340.23MB
#   CPU: 22.7%
#   Loss: 1.3871
#   RMSE: 0.9588
#   MAE: 0.7651
# Epoch 0 - Emisiones: 0.00001895 kg, Acumulado: 0.00001895 kg, Loss: 1.3871
# RMSE: 0.9588
# MAE: 0.7651
# Epoch 1/50, Training Loss: 1.3871, Validation RMSE: 0.9588, Validation MAE: 0.7651
#
# Epoch 1 Metrics:
#   Time: 35.40s
#   Memory: 379.95MB
#   CPU: 57.6%
#   Loss: 0.8630
#   RMSE: 0.9343
#   MAE: 0.7434
# Epoch 1 - Emisiones: 0.00001870 kg, Acumulado: 0.00003765 kg, Loss: 0.8630
# RMSE: 0.9343
# MAE: 0.7434
# Epoch 2/50, Training Loss: 0.8630, Validation RMSE: 0.9343, Validation MAE: 0.7434
#
# Epoch 2 Metrics:
#   Time: 34.44s
#   Memory: 380.95MB
#   CPU: 56.3%
#   Loss: 0.8249
#   RMSE: 0.9274
#   MAE: 0.7372
# Epoch 2 - Emisiones: 0.00001808 kg, Acumulado: 0.00005574 kg, Loss: 0.8249
# RMSE: 0.9274
# MAE: 0.7372
# Epoch 3/50, Training Loss: 0.8249, Validation RMSE: 0.9274, Validation MAE: 0.7372
#
# Epoch 3 Metrics:
#   Time: 33.31s
#   Memory: 381.32MB
#   CPU: 56.6%
#   Loss: 0.8062
#   RMSE: 0.9269
#   MAE: 0.7323
# Epoch 3 - Emisiones: 0.00001742 kg, Acumulado: 0.00007315 kg, Loss: 0.8062
# RMSE: 0.9269
# MAE: 0.7323
# Epoch 4/50, Training Loss: 0.8062, Validation RMSE: 0.9269, Validation MAE: 0.7323
#
# Epoch 4 Metrics:
#   Time: 35.45s
#   Memory: 381.86MB
#   CPU: 52.9%
#   Loss: 0.7935
#   RMSE: 0.9253
#   MAE: 0.7314
# Epoch 4 - Emisiones: 0.00001872 kg, Acumulado: 0.00009187 kg, Loss: 0.7935
# RMSE: 0.9253
# MAE: 0.7314
# Epoch 5/50, Training Loss: 0.7935, Validation RMSE: 0.9253, Validation MAE: 0.7314
#
# Epoch 5 Metrics:
#   Time: 33.26s
#   Memory: 381.93MB
#   CPU: 55.8%
#   Loss: 0.7819
#   RMSE: 0.9244
#   MAE: 0.7311
# Epoch 5 - Emisiones: 0.00001739 kg, Acumulado: 0.00010926 kg, Loss: 0.7819
# RMSE: 0.9244
# MAE: 0.7311
# Epoch 6/50, Training Loss: 0.7819, Validation RMSE: 0.9244, Validation MAE: 0.7311
#
# Epoch 6 Metrics:
#   Time: 33.19s
#   Memory: 382.17MB
#   CPU: 52.3%
#   Loss: 0.7705
#   RMSE: 0.9237
#   MAE: 0.7307
# Epoch 6 - Emisiones: 0.00001738 kg, Acumulado: 0.00012664 kg, Loss: 0.7705
# RMSE: 0.9237
# MAE: 0.7307
# Epoch 7/50, Training Loss: 0.7705, Validation RMSE: 0.9237, Validation MAE: 0.7307
#
# Epoch 7 Metrics:
#   Time: 33.14s
#   Memory: 382.29MB
#   CPU: 52.1%
#   Loss: 0.7590
#   RMSE: 0.9241
#   MAE: 0.7323
# Epoch 7 - Emisiones: 0.00001731 kg, Acumulado: 0.00014394 kg, Loss: 0.7590
# RMSE: 0.9241
# MAE: 0.7323
# Epoch 8/50, Training Loss: 0.7590, Validation RMSE: 0.9241, Validation MAE: 0.7323
#
# Epoch 8 Metrics:
#   Time: 33.07s
#   Memory: 382.43MB
#   CPU: 50.9%
#   Loss: 0.7471
#   RMSE: 0.9263
#   MAE: 0.7290
# Epoch 8 - Emisiones: 0.00001727 kg, Acumulado: 0.00016122 kg, Loss: 0.7471
# RMSE: 0.9263
# MAE: 0.7290
# Epoch 9/50, Training Loss: 0.7471, Validation RMSE: 0.9263, Validation MAE: 0.7290
#
# Epoch 9 Metrics:
#   Time: 33.44s
#   Memory: 382.68MB
#   CPU: 52.5%
#   Loss: 0.7345
#   RMSE: 0.9255
#   MAE: 0.7313
# Epoch 9 - Emisiones: 0.00001752 kg, Acumulado: 0.00017874 kg, Loss: 0.7345
# RMSE: 0.9255
# MAE: 0.7313
# Epoch 10/50, Training Loss: 0.7345, Validation RMSE: 0.9255, Validation MAE: 0.7313
#
# Epoch 10 Metrics:
#   Time: 33.56s
#   Memory: 382.72MB
#   CPU: 51.8%
#   Loss: 0.7219
#   RMSE: 0.9247
#   MAE: 0.7296
# Epoch 10 - Emisiones: 0.00001751 kg, Acumulado: 0.00019624 kg, Loss: 0.7219
# RMSE: 0.9247
# MAE: 0.7296
# Epoch 11/50, Training Loss: 0.7219, Validation RMSE: 0.9247, Validation MAE: 0.7296
#
# Epoch 11 Metrics:
#   Time: 33.24s
#   Memory: 383.03MB
#   CPU: 52.3%
#   Loss: 0.7088
#   RMSE: 0.9262
#   MAE: 0.7311
# Epoch 11 - Emisiones: 0.00001739 kg, Acumulado: 0.00021363 kg, Loss: 0.7088
# RMSE: 0.9262
# MAE: 0.7311
# Epoch 12/50, Training Loss: 0.7088, Validation RMSE: 0.9262, Validation MAE: 0.7311
#
# Epoch 12 Metrics:
#   Time: 32.90s
#   Memory: 383.18MB
#   CPU: 51.7%
#   Loss: 0.6956
#   RMSE: 0.9283
#   MAE: 0.7298
# Epoch 12 - Emisiones: 0.00001718 kg, Acumulado: 0.00023082 kg, Loss: 0.6956
# RMSE: 0.9283
# MAE: 0.7298
# Epoch 13/50, Training Loss: 0.6956, Validation RMSE: 0.9283, Validation MAE: 0.7298
#
# Epoch 13 Metrics:
#   Time: 33.23s
#   Memory: 383.23MB
#   CPU: 50.6%
#   Loss: 0.6825
#   RMSE: 0.9287
#   MAE: 0.7344
# Epoch 13 - Emisiones: 0.00001740 kg, Acumulado: 0.00024821 kg, Loss: 0.6825
# RMSE: 0.9287
# MAE: 0.7344
# Epoch 14/50, Training Loss: 0.6825, Validation RMSE: 0.9287, Validation MAE: 0.7344
#
# Epoch 14 Metrics:
#   Time: 33.00s
#   Memory: 383.27MB
#   CPU: 50.8%
#   Loss: 0.6695
#   RMSE: 0.9326
#   MAE: 0.7337
# Epoch 14 - Emisiones: 0.00001725 kg, Acumulado: 0.00026546 kg, Loss: 0.6695
# RMSE: 0.9326
# MAE: 0.7337
# Epoch 15/50, Training Loss: 0.6695, Validation RMSE: 0.9326, Validation MAE: 0.7337
#
# Epoch 15 Metrics:
#   Time: 32.66s
#   Memory: 383.35MB
#   CPU: 51.5%
#   Loss: 0.6569
#   RMSE: 0.9335
#   MAE: 0.7358
# Epoch 15 - Emisiones: 0.00001706 kg, Acumulado: 0.00028253 kg, Loss: 0.6569
# RMSE: 0.9335
# MAE: 0.7358
# Epoch 16/50, Training Loss: 0.6569, Validation RMSE: 0.9335, Validation MAE: 0.7358
#
# Epoch 16 Metrics:
#   Time: 33.19s
#   Memory: 383.65MB
#   CPU: 50.7%
#   Loss: 0.6445
#   RMSE: 0.9369
#   MAE: 0.7361
# Epoch 16 - Emisiones: 0.00001736 kg, Acumulado: 0.00029988 kg, Loss: 0.6445
# RMSE: 0.9369
# MAE: 0.7361
# Epoch 17/50, Training Loss: 0.6445, Validation RMSE: 0.9369, Validation MAE: 0.7361
#
# Epoch 17 Metrics:
#   Time: 33.61s
#   Memory: 383.68MB
#   CPU: 50.9%
#   Loss: 0.6314
#   RMSE: 0.9383
#   MAE: 0.7409
# Epoch 17 - Emisiones: 0.00001752 kg, Acumulado: 0.00031741 kg, Loss: 0.6314
# RMSE: 0.9383
# MAE: 0.7409
# Epoch 18/50, Training Loss: 0.6314, Validation RMSE: 0.9383, Validation MAE: 0.7409
#
# Epoch 18 Metrics:
#   Time: 33.47s
#   Memory: 383.70MB
#   CPU: 53.7%
#   Loss: 0.6198
#   RMSE: 0.9424
#   MAE: 0.7417
# Epoch 18 - Emisiones: 0.00001756 kg, Acumulado: 0.00033496 kg, Loss: 0.6198
# RMSE: 0.9424
# MAE: 0.7417
# Epoch 19/50, Training Loss: 0.6198, Validation RMSE: 0.9424, Validation MAE: 0.7417
#
# Epoch 19 Metrics:
#   Time: 32.97s
#   Memory: 383.73MB
#   CPU: 52.7%
#   Loss: 0.6074
#   RMSE: 0.9461
#   MAE: 0.7452
# Epoch 19 - Emisiones: 0.00001722 kg, Acumulado: 0.00035219 kg, Loss: 0.6074
# RMSE: 0.9461
# MAE: 0.7452
# Epoch 20/50, Training Loss: 0.6074, Validation RMSE: 0.9461, Validation MAE: 0.7452
#
# Epoch 20 Metrics:
#   Time: 32.97s
#   Memory: 383.74MB
#   CPU: 51.1%
#   Loss: 0.5958
#   RMSE: 0.9462
#   MAE: 0.7445
# Epoch 20 - Emisiones: 0.00001721 kg, Acumulado: 0.00036940 kg, Loss: 0.5958
# RMSE: 0.9462
# MAE: 0.7445
# Epoch 21/50, Training Loss: 0.5958, Validation RMSE: 0.9462, Validation MAE: 0.7445
#
# Epoch 21 Metrics:
#   Time: 33.20s
#   Memory: 383.80MB
#   CPU: 50.4%
#   Loss: 0.5841
#   RMSE: 0.9500
#   MAE: 0.7506
# Epoch 21 - Emisiones: 0.00001736 kg, Acumulado: 0.00038677 kg, Loss: 0.5841
# RMSE: 0.9500
# MAE: 0.7506
# Epoch 22/50, Training Loss: 0.5841, Validation RMSE: 0.9500, Validation MAE: 0.7506
#
# Epoch 22 Metrics:
#   Time: 33.24s
#   Memory: 383.80MB
#   CPU: 51.2%
#   Loss: 0.5728
#   RMSE: 0.9550
#   MAE: 0.7553
# Epoch 22 - Emisiones: 0.00001736 kg, Acumulado: 0.00040412 kg, Loss: 0.5728
# RMSE: 0.9550
# MAE: 0.7553
# Epoch 23/50, Training Loss: 0.5728, Validation RMSE: 0.9550, Validation MAE: 0.7553
#
# Epoch 23 Metrics:
#   Time: 32.99s
#   Memory: 383.84MB
#   CPU: 52.2%
#   Loss: 0.5616
#   RMSE: 0.9584
#   MAE: 0.7541
# Epoch 23 - Emisiones: 0.00001727 kg, Acumulado: 0.00042139 kg, Loss: 0.5616
# RMSE: 0.9584
# MAE: 0.7541
# Epoch 24/50, Training Loss: 0.5616, Validation RMSE: 0.9584, Validation MAE: 0.7541
#
# Epoch 24 Metrics:
#   Time: 33.17s
#   Memory: 383.85MB
#   CPU: 52.1%
#   Loss: 0.5508
#   RMSE: 0.9638
#   MAE: 0.7583
# Epoch 24 - Emisiones: 0.00001735 kg, Acumulado: 0.00043874 kg, Loss: 0.5508
# RMSE: 0.9638
# MAE: 0.7583
# Epoch 25/50, Training Loss: 0.5508, Validation RMSE: 0.9638, Validation MAE: 0.7583
#
# Epoch 25 Metrics:
#   Time: 33.08s
#   Memory: 383.86MB
#   CPU: 52.7%
#   Loss: 0.5404
#   RMSE: 0.9653
#   MAE: 0.7615
# Epoch 25 - Emisiones: 0.00001731 kg, Acumulado: 0.00045605 kg, Loss: 0.5404
# RMSE: 0.9653
# MAE: 0.7615
# Epoch 26/50, Training Loss: 0.5404, Validation RMSE: 0.9653, Validation MAE: 0.7615
#
# Epoch 26 Metrics:
#   Time: 33.57s
#   Memory: 383.87MB
#   CPU: 52.3%
#   Loss: 0.5298
#   RMSE: 0.9683
#   MAE: 0.7635
# Epoch 26 - Emisiones: 0.00001757 kg, Acumulado: 0.00047362 kg, Loss: 0.5298
# RMSE: 0.9683
# MAE: 0.7635
# Epoch 27/50, Training Loss: 0.5298, Validation RMSE: 0.9683, Validation MAE: 0.7635
#
# Epoch 27 Metrics:
#   Time: 34.37s
#   Memory: 380.62MB
#   CPU: 53.3%
#   Loss: 0.5204
#   RMSE: 0.9712
#   MAE: 0.7644
# Epoch 27 - Emisiones: 0.00001809 kg, Acumulado: 0.00049171 kg, Loss: 0.5204
# RMSE: 0.9712
# MAE: 0.7644
# Epoch 28/50, Training Loss: 0.5204, Validation RMSE: 0.9712, Validation MAE: 0.7644
#
# Epoch 28 Metrics:
#   Time: 33.05s
#   Memory: 380.76MB
#   CPU: 53.7%
#   Loss: 0.5111
#   RMSE: 0.9750
#   MAE: 0.7680
# Epoch 28 - Emisiones: 0.00001725 kg, Acumulado: 0.00050897 kg, Loss: 0.5111
# RMSE: 0.9750
# MAE: 0.7680
# Epoch 29/50, Training Loss: 0.5111, Validation RMSE: 0.9750, Validation MAE: 0.7680
#
# Epoch 29 Metrics:
#   Time: 35.30s
#   Memory: 381.34MB
#   CPU: 52.0%
#   Loss: 0.5014
#   RMSE: 0.9773
#   MAE: 0.7711
# Epoch 29 - Emisiones: 0.00001865 kg, Acumulado: 0.00052762 kg, Loss: 0.5014
# RMSE: 0.9773
# MAE: 0.7711
# Epoch 30/50, Training Loss: 0.5014, Validation RMSE: 0.9773, Validation MAE: 0.7711
#
# Epoch 30 Metrics:
#   Time: 33.36s
#   Memory: 381.82MB
#   CPU: 56.0%
#   Loss: 0.4928
#   RMSE: 0.9789
#   MAE: 0.7734
# Epoch 30 - Emisiones: 0.00001745 kg, Acumulado: 0.00054506 kg, Loss: 0.4928
# RMSE: 0.9789
# MAE: 0.7734
# Epoch 31/50, Training Loss: 0.4928, Validation RMSE: 0.9789, Validation MAE: 0.7734
#
# Epoch 31 Metrics:
#   Time: 33.08s
#   Memory: 381.92MB
#   CPU: 53.0%
#   Loss: 0.4836
#   RMSE: 0.9840
#   MAE: 0.7763
# Epoch 31 - Emisiones: 0.00001729 kg, Acumulado: 0.00056235 kg, Loss: 0.4836
# RMSE: 0.9840
# MAE: 0.7763
# Epoch 32/50, Training Loss: 0.4836, Validation RMSE: 0.9840, Validation MAE: 0.7763
#
# Epoch 32 Metrics:
#   Time: 33.15s
#   Memory: 382.02MB
#   CPU: 52.4%
#   Loss: 0.4756
#   RMSE: 0.9852
#   MAE: 0.7768
# Epoch 32 - Emisiones: 0.00001735 kg, Acumulado: 0.00057970 kg, Loss: 0.4756
# RMSE: 0.9852
# MAE: 0.7768
# Epoch 33/50, Training Loss: 0.4756, Validation RMSE: 0.9852, Validation MAE: 0.7768
#
# Epoch 33 Metrics:
#   Time: 32.71s
#   Memory: 382.06MB
#   CPU: 51.8%
#   Loss: 0.4675
#   RMSE: 0.9892
#   MAE: 0.7804
# Epoch 33 - Emisiones: 0.00001708 kg, Acumulado: 0.00059678 kg, Loss: 0.4675
# RMSE: 0.9892
# MAE: 0.7804
# Epoch 34/50, Training Loss: 0.4675, Validation RMSE: 0.9892, Validation MAE: 0.7804
#
# Epoch 34 Metrics:
#   Time: 33.30s
#   Memory: 382.18MB
#   CPU: 50.6%
#   Loss: 0.4591
#   RMSE: 0.9931
#   MAE: 0.7812
# Epoch 34 - Emisiones: 0.00001741 kg, Acumulado: 0.00061419 kg, Loss: 0.4591
# RMSE: 0.9931
# MAE: 0.7812
# Epoch 35/50, Training Loss: 0.4591, Validation RMSE: 0.9931, Validation MAE: 0.7812
#
# Epoch 35 Metrics:
#   Time: 32.95s
#   Memory: 382.19MB
#   CPU: 51.8%
#   Loss: 0.4515
#   RMSE: 0.9946
#   MAE: 0.7842
# Epoch 35 - Emisiones: 0.00001723 kg, Acumulado: 0.00063142 kg, Loss: 0.4515
# RMSE: 0.9946
# MAE: 0.7842
# Epoch 36/50, Training Loss: 0.4515, Validation RMSE: 0.9946, Validation MAE: 0.7842
#
# Epoch 36 Metrics:
#   Time: 38.81s
#   Memory: 382.46MB
#   CPU: 51.3%
#   Loss: 0.4446
#   RMSE: 0.9981
#   MAE: 0.7871
# Epoch 36 - Emisiones: 0.00002080 kg, Acumulado: 0.00065222 kg, Loss: 0.4446
# RMSE: 0.9981
# MAE: 0.7871
# Epoch 37/50, Training Loss: 0.4446, Validation RMSE: 0.9981, Validation MAE: 0.7871
#
# Epoch 37 Metrics:
#   Time: 36.64s
#   Memory: 382.48MB
#   CPU: 65.7%
#   Loss: 0.4372
#   RMSE: 1.0025
#   MAE: 0.7885
# Epoch 37 - Emisiones: 0.00001927 kg, Acumulado: 0.00067150 kg, Loss: 0.4372
# RMSE: 1.0025
# MAE: 0.7885
# Epoch 38/50, Training Loss: 0.4372, Validation RMSE: 1.0025, Validation MAE: 0.7885
#
# Epoch 38 Metrics:
#   Time: 34.24s
#   Memory: 382.54MB
#   CPU: 59.0%
#   Loss: 0.4302
#   RMSE: 1.0040
#   MAE: 0.7906
# Epoch 38 - Emisiones: 0.00001796 kg, Acumulado: 0.00068946 kg, Loss: 0.4302
# RMSE: 1.0040
# MAE: 0.7906
# Epoch 39/50, Training Loss: 0.4302, Validation RMSE: 1.0040, Validation MAE: 0.7906
#
# Epoch 39 Metrics:
#   Time: 33.92s
#   Memory: 382.55MB
#   CPU: 54.0%
#   Loss: 0.4232
#   RMSE: 1.0057
#   MAE: 0.7931
# Epoch 39 - Emisiones: 0.00001778 kg, Acumulado: 0.00070724 kg, Loss: 0.4232
# RMSE: 1.0057
# MAE: 0.7931
# Epoch 40/50, Training Loss: 0.4232, Validation RMSE: 1.0057, Validation MAE: 0.7931
#
# Epoch 40 Metrics:
#   Time: 33.57s
#   Memory: 382.55MB
#   CPU: 53.0%
#   Loss: 0.4174
#   RMSE: 1.0086
#   MAE: 0.7960
# Epoch 40 - Emisiones: 0.00001752 kg, Acumulado: 0.00072475 kg, Loss: 0.4174
# RMSE: 1.0086
# MAE: 0.7960
# Epoch 41/50, Training Loss: 0.4174, Validation RMSE: 1.0086, Validation MAE: 0.7960
#
# Epoch 41 Metrics:
#   Time: 35.54s
#   Memory: 382.60MB
#   CPU: 52.7%
#   Loss: 0.4105
#   RMSE: 1.0119
#   MAE: 0.7980
# Epoch 41 - Emisiones: 0.00001879 kg, Acumulado: 0.00074355 kg, Loss: 0.4105
# RMSE: 1.0119
# MAE: 0.7980
# Epoch 42/50, Training Loss: 0.4105, Validation RMSE: 1.0119, Validation MAE: 0.7980
#
# Epoch 42 Metrics:
#   Time: 33.09s
#   Memory: 382.63MB
#   CPU: 55.8%
#   Loss: 0.4049
#   RMSE: 1.0133
#   MAE: 0.7995
# Epoch 42 - Emisiones: 0.00001731 kg, Acumulado: 0.00076086 kg, Loss: 0.4049
# RMSE: 1.0133
# MAE: 0.7995
# Epoch 43/50, Training Loss: 0.4049, Validation RMSE: 1.0133, Validation MAE: 0.7995
#
# Epoch 43 Metrics:
#   Time: 33.48s
#   Memory: 382.65MB
#   CPU: 51.2%
#   Loss: 0.3983
#   RMSE: 1.0173
#   MAE: 0.8023
# Epoch 43 - Emisiones: 0.00001752 kg, Acumulado: 0.00077838 kg, Loss: 0.3983
# RMSE: 1.0173
# MAE: 0.8023
# Epoch 44/50, Training Loss: 0.3983, Validation RMSE: 1.0173, Validation MAE: 0.8023
#
# Epoch 44 Metrics:
#   Time: 33.32s
#   Memory: 382.66MB
#   CPU: 51.9%
#   Loss: 0.3929
#   RMSE: 1.0186
#   MAE: 0.8042
# Epoch 44 - Emisiones: 0.00001744 kg, Acumulado: 0.00079581 kg, Loss: 0.3929
# RMSE: 1.0186
# MAE: 0.8042
# Epoch 45/50, Training Loss: 0.3929, Validation RMSE: 1.0186, Validation MAE: 0.8042
#
# Epoch 45 Metrics:
#   Time: 32.77s
#   Memory: 382.76MB
#   CPU: 52.4%
#   Loss: 0.3874
#   RMSE: 1.0214
#   MAE: 0.8045
# Epoch 45 - Emisiones: 0.00001711 kg, Acumulado: 0.00081292 kg, Loss: 0.3874
# RMSE: 1.0214
# MAE: 0.8045
# Epoch 46/50, Training Loss: 0.3874, Validation RMSE: 1.0214, Validation MAE: 0.8045
#
# Epoch 46 Metrics:
#   Time: 35.91s
#   Memory: 382.79MB
#   CPU: 51.6%
#   Loss: 0.3822
#   RMSE: 1.0238
#   MAE: 0.8073
# Epoch 46 - Emisiones: 0.00001901 kg, Acumulado: 0.00083193 kg, Loss: 0.3822
# RMSE: 1.0238
# MAE: 0.8073
# Epoch 47/50, Training Loss: 0.3822, Validation RMSE: 1.0238, Validation MAE: 0.8073
#
# Epoch 47 Metrics:
#   Time: 45.86s
#   Memory: 382.80MB
#   CPU: 56.1%
#   Loss: 0.3767
#   RMSE: 1.0258
#   MAE: 0.8100
# Epoch 47 - Emisiones: 0.00002456 kg, Acumulado: 0.00085649 kg, Loss: 0.3767
# RMSE: 1.0258
# MAE: 0.8100
# Epoch 48/50, Training Loss: 0.3767, Validation RMSE: 1.0258, Validation MAE: 0.8100
#
# Epoch 48 Metrics:
#   Time: 33.69s
#   Memory: 382.84MB
#   CPU: 74.4%
#   Loss: 0.3716
#   RMSE: 1.0273
#   MAE: 0.8115
# Epoch 48 - Emisiones: 0.00001765 kg, Acumulado: 0.00087414 kg, Loss: 0.3716
# RMSE: 1.0273
# MAE: 0.8115
# Epoch 49/50, Training Loss: 0.3716, Validation RMSE: 1.0273, Validation MAE: 0.8115
#
# Epoch 49 Metrics:
#   Time: 33.13s
#   Memory: 383.02MB
#   CPU: 53.2%
#   Loss: 0.3666
#   RMSE: 1.0312
#   MAE: 0.8113
# Epoch 49 - Emisiones: 0.00001730 kg, Acumulado: 0.00089144 kg, Loss: 0.3666
# RMSE: 1.0312
# MAE: 0.8113
# Epoch 50/50, Training Loss: 0.3666, Validation RMSE: 1.0312, Validation MAE: 0.8113
#
# Evaluando modelo en conjunto de prueba final...
#
# Generando métricas finales del sistema con SystemMetricsTracker...
#
# === Final Training Metrics ===
# Epoch 0: Time=35.85s, Memory=340.23MB, CPU=22.7%, Loss=1.3871, RMSE=0.9588, MAE=0.7651
# Epoch 1: Time=35.40s, Memory=379.95MB, CPU=57.6%, Loss=0.8630, RMSE=0.9343, MAE=0.7434
# Epoch 2: Time=34.44s, Memory=380.95MB, CPU=56.3%, Loss=0.8249, RMSE=0.9274, MAE=0.7372
# Epoch 3: Time=33.31s, Memory=381.32MB, CPU=56.6%, Loss=0.8062, RMSE=0.9269, MAE=0.7323
# Epoch 4: Time=35.45s, Memory=381.86MB, CPU=52.9%, Loss=0.7935, RMSE=0.9253, MAE=0.7314
# Epoch 5: Time=33.26s, Memory=381.93MB, CPU=55.8%, Loss=0.7819, RMSE=0.9244, MAE=0.7311
# Epoch 6: Time=33.19s, Memory=382.17MB, CPU=52.3%, Loss=0.7705, RMSE=0.9237, MAE=0.7307
# Epoch 7: Time=33.14s, Memory=382.29MB, CPU=52.1%, Loss=0.7590, RMSE=0.9241, MAE=0.7323
# Epoch 8: Time=33.07s, Memory=382.43MB, CPU=50.9%, Loss=0.7471, RMSE=0.9263, MAE=0.7290
# Epoch 9: Time=33.44s, Memory=382.68MB, CPU=52.5%, Loss=0.7345, RMSE=0.9255, MAE=0.7313
# Epoch 10: Time=33.56s, Memory=382.72MB, CPU=51.8%, Loss=0.7219, RMSE=0.9247, MAE=0.7296
# Epoch 11: Time=33.24s, Memory=383.03MB, CPU=52.3%, Loss=0.7088, RMSE=0.9262, MAE=0.7311
# Epoch 12: Time=32.90s, Memory=383.18MB, CPU=51.7%, Loss=0.6956, RMSE=0.9283, MAE=0.7298
# Epoch 13: Time=33.23s, Memory=383.23MB, CPU=50.6%, Loss=0.6825, RMSE=0.9287, MAE=0.7344
# Epoch 14: Time=33.00s, Memory=383.27MB, CPU=50.8%, Loss=0.6695, RMSE=0.9326, MAE=0.7337
# Epoch 15: Time=32.66s, Memory=383.35MB, CPU=51.5%, Loss=0.6569, RMSE=0.9335, MAE=0.7358
# Epoch 16: Time=33.19s, Memory=383.65MB, CPU=50.7%, Loss=0.6445, RMSE=0.9369, MAE=0.7361
# Epoch 17: Time=33.61s, Memory=383.68MB, CPU=50.9%, Loss=0.6314, RMSE=0.9383, MAE=0.7409
# Epoch 18: Time=33.47s, Memory=383.70MB, CPU=53.7%, Loss=0.6198, RMSE=0.9424, MAE=0.7417
# Epoch 19: Time=32.97s, Memory=383.73MB, CPU=52.7%, Loss=0.6074, RMSE=0.9461, MAE=0.7452
# Epoch 20: Time=32.97s, Memory=383.74MB, CPU=51.1%, Loss=0.5958, RMSE=0.9462, MAE=0.7445
# Epoch 21: Time=33.20s, Memory=383.80MB, CPU=50.4%, Loss=0.5841, RMSE=0.9500, MAE=0.7506
# Epoch 22: Time=33.24s, Memory=383.80MB, CPU=51.2%, Loss=0.5728, RMSE=0.9550, MAE=0.7553
# Epoch 23: Time=32.99s, Memory=383.84MB, CPU=52.2%, Loss=0.5616, RMSE=0.9584, MAE=0.7541
# Epoch 24: Time=33.17s, Memory=383.85MB, CPU=52.1%, Loss=0.5508, RMSE=0.9638, MAE=0.7583
# Epoch 25: Time=33.08s, Memory=383.86MB, CPU=52.7%, Loss=0.5404, RMSE=0.9653, MAE=0.7615
# Epoch 26: Time=33.57s, Memory=383.87MB, CPU=52.3%, Loss=0.5298, RMSE=0.9683, MAE=0.7635
# Epoch 27: Time=34.37s, Memory=380.62MB, CPU=53.3%, Loss=0.5204, RMSE=0.9712, MAE=0.7644
# Epoch 28: Time=33.05s, Memory=380.76MB, CPU=53.7%, Loss=0.5111, RMSE=0.9750, MAE=0.7680
# Epoch 29: Time=35.30s, Memory=381.34MB, CPU=52.0%, Loss=0.5014, RMSE=0.9773, MAE=0.7711
# Epoch 30: Time=33.36s, Memory=381.82MB, CPU=56.0%, Loss=0.4928, RMSE=0.9789, MAE=0.7734
# Epoch 31: Time=33.08s, Memory=381.92MB, CPU=53.0%, Loss=0.4836, RMSE=0.9840, MAE=0.7763
# Epoch 32: Time=33.15s, Memory=382.02MB, CPU=52.4%, Loss=0.4756, RMSE=0.9852, MAE=0.7768
# Epoch 33: Time=32.71s, Memory=382.06MB, CPU=51.8%, Loss=0.4675, RMSE=0.9892, MAE=0.7804
# Epoch 34: Time=33.30s, Memory=382.18MB, CPU=50.6%, Loss=0.4591, RMSE=0.9931, MAE=0.7812
# Epoch 35: Time=32.95s, Memory=382.19MB, CPU=51.8%, Loss=0.4515, RMSE=0.9946, MAE=0.7842
# Epoch 36: Time=38.81s, Memory=382.46MB, CPU=51.3%, Loss=0.4446, RMSE=0.9981, MAE=0.7871
# Epoch 37: Time=36.64s, Memory=382.48MB, CPU=65.7%, Loss=0.4372, RMSE=1.0025, MAE=0.7885
# Epoch 38: Time=34.24s, Memory=382.54MB, CPU=59.0%, Loss=0.4302, RMSE=1.0040, MAE=0.7906
# Epoch 39: Time=33.92s, Memory=382.55MB, CPU=54.0%, Loss=0.4232, RMSE=1.0057, MAE=0.7931
# Epoch 40: Time=33.57s, Memory=382.55MB, CPU=53.0%, Loss=0.4174, RMSE=1.0086, MAE=0.7960
# Epoch 41: Time=35.54s, Memory=382.60MB, CPU=52.7%, Loss=0.4105, RMSE=1.0119, MAE=0.7980
# Epoch 42: Time=33.09s, Memory=382.63MB, CPU=55.8%, Loss=0.4049, RMSE=1.0133, MAE=0.7995
# Epoch 43: Time=33.48s, Memory=382.65MB, CPU=51.2%, Loss=0.3983, RMSE=1.0173, MAE=0.8023
# Epoch 44: Time=33.32s, Memory=382.66MB, CPU=51.9%, Loss=0.3929, RMSE=1.0186, MAE=0.8042
# Epoch 45: Time=32.77s, Memory=382.76MB, CPU=52.4%, Loss=0.3874, RMSE=1.0214, MAE=0.8045
# Epoch 46: Time=35.91s, Memory=382.79MB, CPU=51.6%, Loss=0.3822, RMSE=1.0238, MAE=0.8073
# Epoch 47: Time=45.86s, Memory=382.80MB, CPU=56.1%, Loss=0.3767, RMSE=1.0258, MAE=0.8100
# Epoch 48: Time=33.69s, Memory=382.84MB, CPU=74.4%, Loss=0.3716, RMSE=1.0273, MAE=0.8115
# Epoch 49: Time=33.13s, Memory=383.02MB, CPU=53.2%, Loss=0.3666, RMSE=1.0312, MAE=0.8113
#
# === Final Test Metrics ===
# Total Time: 1712.02s (Test: 4.77s)
# Final Memory: 383.09MB
# Final CPU: 63.8%
# Test RMSE: 1.0312
# Test MAE: 0.8113
#
# Generando gráficos y métricas de emisiones...
#
# Total CO2 Emissions: 0.001043 kg
# Métricas de emisiones guardadas en: results/emissions_reports/emissions_metrics_NCF_20250423-130208.csv
# Gráfico guardado en: results/emissions_plots/cumulative_emissions_vs_rmse_NCF_20250423-130208.png
# Gráfico guardado en: results/emissions_plots/metrics_by_epoch_NCF_20250423-130208.png
# Gráfico guardado en: results/emissions_plots/cumulative_emissions_performance_scatter_NCF_20250423-130208.png
# Gráfico comparativo guardado en: results/emissions_plots/rmse_vs_mae_NCF_20250423-130208.png
# Métricas del modelo guardadas en: results/model_metrics_20250423-130210.csv
#
# ============================================================
# MÉTRICAS FINALES DEL SISTEMA (MEDICIÓN INDEPENDIENTE GARANTIZADA)
# ============================================================
# Memoria final: 397.25 MB
# CPU final: 25.40%
# Tiempo total de ejecución: 1712.04 segundos
# RMSE final: 1.0312
# MAE final: 0.8113
# ============================================================
# Métricas finales guardadas en: results/final_metrics_20250423-130210.csv
#
# Entrenamiento finalizado!
# Métricas finales - RMSE: 1.0312, MAE: 0.8113
# Programa finalizado correctamente.
