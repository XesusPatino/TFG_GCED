# %%
import torch
import torch.nn as nn
import torch.optim as optim
import pandas as pd
import numpy as np
import os
import time
import psutil
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from torch.utils.data import DataLoader, Dataset
from sklearn.preprocessing import LabelEncoder
from codecarbon import EmissionsTracker
from collections import defaultdict
import random

# %% [markdown]
# # **Directorio para resultados**

# %%
result_path = "results"
os.makedirs(result_path, exist_ok=True)
os.makedirs(f"{result_path}/emissions_reports", exist_ok=True)
os.makedirs(f"{result_path}/emissions_plots", exist_ok=True)

# %% [markdown]
# # **Parámetros de entrenamiento**

# %%
config = {
    'embedding_dim': 128,
    'hidden_dim': 128,
    'batch_size': 1024,
    'learning_rate': 1e-3,
    'epochs': 50,
    'display_step': 1,
    'test_size': 0.2,
    'random_state': 42,
    'top_k_values': [5, 10, 20]  # Valores de K para las métricas Top-K
}

# %% [markdown]
# # **Clase para el seguimiento de métricas del sistema**

# %%
class SystemMetricsTracker:
    def __init__(self):
        self.train_metrics = []
        self.test_metrics = {}
        self.start_time = time.time()
        
    def start_epoch(self, epoch):
        self.epoch_start_time = time.time()
        self.current_epoch_metrics = {
            'epoch': epoch,
            'memory_usage_mb': psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2,
            'cpu_usage_percent': psutil.cpu_percent(),
        }
        
    def end_epoch(self, epoch, loss, rmse=None, mae=None):
        epoch_time = time.time() - self.epoch_start_time
        self.current_epoch_metrics['epoch_time_sec'] = epoch_time
        self.current_epoch_metrics['loss'] = loss
        if rmse is not None:
            self.current_epoch_metrics['rmse'] = rmse
        if mae is not None:
            self.current_epoch_metrics['mae'] = mae
        self.train_metrics.append(self.current_epoch_metrics)
        
        # Imprimir resumen de época
        print(f"\nEpoch {epoch} Metrics:")
        print(f"  Time: {epoch_time:.2f}s")
        print(f"  Memory: {self.current_epoch_metrics['memory_usage_mb']:.2f}MB")
        print(f"  CPU: {self.current_epoch_metrics['cpu_usage_percent']:.1f}%")
        print(f"  Loss: {loss:.4f}")
        if rmse is not None:
            print(f"  RMSE: {rmse:.4f}")
        if mae is not None:
            print(f"  MAE: {mae:.4f}")
        
    def end_test(self, rmse, mae=None):
        self.test_metrics = {
            'test_time_sec': time.time() - self.epoch_start_time,
            'total_time_sec': time.time() - self.start_time,
            'final_memory_usage_mb': psutil.Process(os.getpid()).memory_info().rss / 1024 ** 2,
            'final_cpu_usage_percent': psutil.cpu_percent(),
            'test_rmse': rmse,
        }
        if mae is not None:
            self.test_metrics['test_mae'] = mae
        
        # Imprimir métricas finales
        print("\n=== Final Training Metrics ===")
        for m in self.train_metrics:
            metrics_str = f"Epoch {m['epoch']}: Time={m['epoch_time_sec']:.2f}s, Memory={m['memory_usage_mb']:.2f}MB, CPU={m['cpu_usage_percent']:.1f}%, Loss={m['loss']:.4f}"
            if 'rmse' in m:
                metrics_str += f", RMSE={m['rmse']:.4f}"
            if 'mae' in m:
                metrics_str += f", MAE={m['mae']:.4f}"
            print(metrics_str)
        
        print("\n=== Final Test Metrics ===")
        print(f"Total Time: {self.test_metrics['total_time_sec']:.2f}s (Test: {self.test_metrics['test_time_sec']:.2f}s)")
        print(f"Final Memory: {self.test_metrics['final_memory_usage_mb']:.2f}MB")
        print(f"Final CPU: {self.test_metrics['final_cpu_usage_percent']:.1f}%")
        print(f"Test RMSE: {rmse:.4f}")
        if mae is not None:
            print(f"Test MAE: {mae:.4f}")
        
        # Guardar métricas en CSV
        timestamp = time.strftime("%Y%m%d-%H%M%S")
        metrics_df = pd.DataFrame(self.train_metrics)
        metrics_df.to_csv(f"{result_path}/system_metrics_{timestamp}.csv", index=False)

# %% [markdown]
# # **Clase para seguimiento de emisiones por época**

# %%
class EmissionsPerEpochTracker:
    def __init__(self, result_path, model_name="NCF"):
        self.result_path = result_path
        self.model_name = model_name
        self.epoch_emissions = []
        self.cumulative_emissions = []
        self.epoch_rmse = []
        self.epoch_mae = []
        self.epoch_loss = []
        self.total_emissions = 0.0
        self.trackers = {}
        
        # Inicializar tracker principal
        self.main_tracker = EmissionsTracker(
            project_name=f"{model_name}_total",
            output_dir=f"{result_path}/emissions_reports",
            save_to_file=True,
            log_level="error",
            save_to_api=False,
            tracking_mode="process"
        )
        try:
            self.main_tracker.start()
            print("Tracker principal iniciado correctamente")
        except Exception as e:
            print(f"Advertencia: No se pudo iniciar el tracker principal: {e}")
            self.main_tracker = None
    
    def start_epoch(self, epoch):
        # Crear un tracker con un nombre único basado en timestamp
        timestamp = int(time.time())
        tracker_name = f"{self.model_name}_epoch{epoch}_{timestamp}"
        
        self.trackers[epoch] = EmissionsTracker(
            project_name=tracker_name,
            output_dir=f"{self.result_path}/emissions_reports",
            save_to_file=True,
            log_level="error",
            save_to_api=False,
            tracking_mode="process",
            measure_power_secs=1,
            allow_multiple_runs=True
        )
        try:
            self.trackers[epoch].start()
        except Exception as e:
            print(f"Advertencia: No se pudo iniciar el tracker para la época {epoch}: {e}")
            self.trackers[epoch] = None
    
    def end_epoch(self, epoch, loss, rmse=None, mae=None):
        try:
            epoch_co2 = 0.0
            if epoch in self.trackers and self.trackers[epoch]:
                try:
                    epoch_co2 = self.trackers[epoch].stop() or 0.0
                except Exception as e:
                    print(f"Advertencia: Error al detener el tracker para la época {epoch}: {e}")
                    epoch_co2 = 0.0
            
            # Acumular emisiones totales
            self.total_emissions += epoch_co2
            
            # Guardar datos de esta época
            self.epoch_emissions.append(epoch_co2)
            self.cumulative_emissions.append(self.total_emissions)
            self.epoch_loss.append(loss)
            if rmse is not None:
                self.epoch_rmse.append(rmse)
            if mae is not None:
                self.epoch_mae.append(mae)
            
            print(f"Epoch {epoch} - Emisiones: {epoch_co2:.8f} kg, Acumulado: {self.total_emissions:.8f} kg, Loss: {loss:.4f}")
            if rmse is not None:
                print(f"RMSE: {rmse:.4f}")
            if mae is not None:
                print(f"MAE: {mae:.4f}")
        except Exception as e:
            print(f"Error al medir emisiones en época {epoch}: {e}")
    
    def end_training(self, final_rmse, final_mae=None):
        try:
            # Detener el tracker principal
            final_emissions = 0.0
            if hasattr(self, 'main_tracker') and self.main_tracker:
                try:
                    final_emissions = self.main_tracker.stop() or 0.0
                    print(f"\nTotal CO2 Emissions: {final_emissions:.6f} kg")
                except Exception as e:
                    print(f"Error al detener el tracker principal: {e}")
                    final_emissions = self.total_emissions
            else:
                final_emissions = self.total_emissions
            
            # Asegurarse de que todos los trackers estén detenidos
            for epoch, tracker in self.trackers.items():
                if tracker is not None:
                    try:
                        tracker.stop()
                    except:
                        pass
            
            # Si no hay datos de emisiones por época pero tenemos emisiones totales,
            # crear al menos una entrada para gráficos
            if not self.epoch_emissions and final_emissions > 0:
                self.epoch_emissions = [final_emissions]
                self.cumulative_emissions = [final_emissions]
                if final_rmse is not None:
                    self.epoch_rmse = [final_rmse]
                if final_mae is not None:
                    self.epoch_mae = [final_mae]
            
            # Si no hay datos, salir
            if not self.epoch_emissions:
                print("No hay datos de emisiones para graficar")
                return
            
            # Asegurarse de que tengamos un RMSE final si no se rastreó por época
            if not self.epoch_rmse and final_rmse is not None:
                self.epoch_rmse = [final_rmse] * len(self.epoch_emissions)
            
            # Crear dataframe con todos los datos
            timestamp = time.strftime("%Y%m%d-%H%M%S")
            df = pd.DataFrame({
                'epoch': range(len(self.epoch_emissions)),
                'epoch_emissions_kg': self.epoch_emissions,
                'cumulative_emissions_kg': self.cumulative_emissions,
                'loss': self.epoch_loss if self.epoch_loss else [0.0] * len(self.epoch_emissions),
                'rmse': self.epoch_rmse if self.epoch_rmse else [None] * len(self.epoch_emissions),
                'mae': self.epoch_mae if self.epoch_mae else [None] * len(self.epoch_emissions)
            })
            
            emissions_file = f'{self.result_path}/emissions_reports/emissions_metrics_{self.model_name}_{timestamp}.csv'
            df.to_csv(emissions_file, index=False)
            print(f"Métricas de emisiones guardadas en: {emissions_file}")
            
            # Graficar las relaciones
            self.plot_emissions_vs_metrics(timestamp, final_rmse, final_mae)
            
        except Exception as e:
            print(f"Error al generar gráficos de emisiones: {e}")
            import traceback
            traceback.print_exc()
    
    def plot_emissions_vs_metrics(self, timestamp, final_rmse=None, final_mae=None):
        """Genera gráficos para emisiones vs métricas"""
        
        # Configurar estilo para fondo blanco y texto negro (más legible)
        plt.style.use('default')
        
        # Usar RMSE por época si está disponible, sino crear lista con el RMSE final
        if not self.epoch_rmse and final_rmse is not None:
            self.epoch_rmse = [final_rmse] * len(self.epoch_emissions)
        
        try:
            if self.epoch_rmse:
                # 1. Emisiones acumulativas vs RMSE
                plt.figure(figsize=(10, 6), facecolor='white')
                plt.plot(self.cumulative_emissions, self.epoch_rmse, 'b-', marker='o')
                
                # Añadir etiquetas con el número de época
                for i, (emissions, rmse) in enumerate(zip(self.cumulative_emissions, self.epoch_rmse)):
                    plt.annotate(f"{i}", (emissions, rmse), textcoords="offset points", 
                                xytext=(0,10), ha='center', fontsize=9, color='black')
                    
                plt.xlabel('Emisiones de CO2 acumuladas (kg)', color='black')
                plt.ylabel('RMSE', color='black')
                plt.title('Relación entre Emisiones Acumuladas y RMSE', color='black')
                plt.grid(True, alpha=0.3)
                plt.tick_params(colors='black')
                
                file_path = f'{self.result_path}/emissions_plots/cumulative_emissions_vs_rmse_{self.model_name}_{timestamp}.png'
                plt.savefig(file_path, facecolor='white')
                plt.close()
                print(f"Gráfico guardado en: {file_path}")
            
            # 2. Gráfico combinado: Emisiones por época y acumulativas
            plt.figure(figsize=(12, 10), facecolor='white')
            
            plt.subplot(2, 2, 1)
            plt.plot(range(len(self.epoch_emissions)), self.epoch_emissions, 'r-', marker='x')
            plt.title('Emisiones por Época', color='black')
            plt.xlabel('Época', color='black')
            plt.ylabel('CO2 Emissions (kg)', color='black')
            plt.tick_params(colors='black')
            
            plt.subplot(2, 2, 2)
            plt.plot(range(len(self.cumulative_emissions)), self.cumulative_emissions, 'r-', marker='o')
            plt.title('Emisiones Acumuladas por Época', color='black')
            plt.xlabel('Época', color='black')
            plt.ylabel('CO2 Emissions (kg)', color='black')
            plt.tick_params(colors='black')
            
            if self.epoch_loss:
                plt.subplot(2, 2, 3)
                plt.plot(range(len(self.epoch_loss)), self.epoch_loss, 'g-', marker='o')
                plt.title('Loss por Época', color='black')
                plt.xlabel('Época', color='black')
                plt.ylabel('Loss', color='black')
                plt.tick_params(colors='black')
            
            if self.epoch_rmse:
                plt.subplot(2, 2, 4)
                plt.plot(range(len(self.epoch_rmse)), self.epoch_rmse, 'b-', marker='o')
                plt.title('RMSE por Época', color='black')
                plt.xlabel('Época', color='black')
                plt.ylabel('RMSE', color='black')
                plt.tick_params(colors='black')
            
            plt.tight_layout()
            
            file_path = f'{self.result_path}/emissions_plots/metrics_by_epoch_{self.model_name}_{timestamp}.png'
            plt.savefig(file_path, facecolor='white')
            plt.close()
            print(f"Gráfico guardado en: {file_path}")
            
            if self.epoch_rmse:
                # 3. Scatter plot de rendimiento frente a emisiones acumulativas
                plt.figure(figsize=(10, 6), facecolor='white')
                
                # Ajustar tamaño de los puntos según la época
                sizes = [(i+1)*20 for i in range(len(self.cumulative_emissions))]
                
                scatter = plt.scatter(self.epoch_rmse, self.cumulative_emissions, 
                            color='blue', marker='o', s=sizes, alpha=0.7)
                
                # Añadir etiquetas de época
                for i, (rmse, em) in enumerate(zip(self.epoch_rmse, self.cumulative_emissions)):
                    plt.annotate(f"{i}", (rmse, em), textcoords="offset points", 
                                xytext=(0,5), ha='center', fontsize=9, color='black')
                
                plt.ylabel('Emisiones de CO2 acumuladas (kg)', color='black')
                plt.xlabel('RMSE', color='black')
                plt.title('Relación entre RMSE y Emisiones Acumuladas', color='black')
                plt.grid(True, alpha=0.3)
                plt.tick_params(colors='black')
                
                file_path = f'{self.result_path}/emissions_plots/cumulative_emissions_performance_scatter_{self.model_name}_{timestamp}.png'
                plt.savefig(file_path, facecolor='white')
                plt.close()
                print(f"Gráfico guardado en: {file_path}")
                
            # 4. Si tenemos RMSE y MAE, crear un gráfico comparativo
            if self.epoch_mae and self.epoch_rmse:
                plt.figure(figsize=(10, 6), facecolor='white')
                plt.plot(range(len(self.epoch_rmse)), self.epoch_rmse, 'b-', marker='o', label='RMSE')
                plt.plot(range(len(self.epoch_mae)), self.epoch_mae, 'g-', marker='s', label='MAE')
                plt.title('Comparación de RMSE y MAE por Época', color='black')
                plt.xlabel('Época', color='black')
                plt.ylabel('Error', color='black')
                plt.legend()
                plt.grid(True, alpha=0.3)
                plt.tick_params(colors='black')
                
                file_path = f'{self.result_path}/emissions_plots/rmse_vs_mae_{self.model_name}_{timestamp}.png'
                plt.savefig(file_path, facecolor='white')
                plt.close()
                print(f"Gráfico comparativo guardado en: {file_path}")
                
        except Exception as e:
            print(f"Error al generar los gráficos: {e}")
            import traceback
            traceback.print_exc()

# %% [markdown]
# # **Cargar el dataset**

# %%
# Load MovieLens dataset
movies_df = pd.read_csv('C://Users//xpati//Documents//TFG//ml-1m//movies.dat', 
                       sep='::', 
                       header=None, 
                       names=['movieId', 'title', 'genres'],
                       encoding='latin-1',
                       engine='python')

ratings_df = pd.read_csv('C://Users//xpati//Documents//TFG//ml-1m//ratings.dat', 
                        sep='::', 
                        header=None, 
                        names=['userId', 'movieId', 'rating', 'timestamp'],
                        encoding='latin-1',
                        engine='python')

# Display first few rows
print(movies_df.head())
print(ratings_df.head())
# Out:
#    movieId                               title                        genres
# 0        1                    Toy Story (1995)   Animation|Children's|Comedy
# 1        2                      Jumanji (1995)  Adventure|Children's|Fantasy
# 2        3             Grumpier Old Men (1995)                Comedy|Romance
# 3        4            Waiting to Exhale (1995)                  Comedy|Drama
# 4        5  Father of the Bride Part II (1995)                        Comedy
#    userId  movieId  rating  timestamp
# 0       1     1193       5  978300760
# 1       1      661       3  978302109
# 2       1      914       3  978301968
# 3       1     3408       4  978300275
# 4       1     2355       5  978824291

# %%
# Label encoding of user and movie IDs
user_encoder = LabelEncoder()
movie_encoder = LabelEncoder()

ratings_df['userId'] = user_encoder.fit_transform(ratings_df['userId'])
ratings_df['movieId'] = movie_encoder.fit_transform(ratings_df['movieId'])

# Obtener número de usuarios y películas únicas
n_users = len(user_encoder.classes_)
n_movies = len(movie_encoder.classes_)

print(f'Number of users: {n_users}')
print(f'Number of movies: {n_movies}')
# Out:
# Number of users: 6040
# Number of movies: 3706

# %%
class BPRDataset(Dataset):
    def __init__(self, ratings_df):
        self.ratings_df = ratings_df
        self.user_item_map = defaultdict(list)
        
        # Mapeo de usuario a ítems positivos (valorados)
        for _, row in ratings_df.iterrows():
            self.user_item_map[row['userId']].append(row['movieId'])
        
        # Lista de todos los ítems para muestreo negativo
        self.all_items = ratings_df['movieId'].unique()
        self.users = list(self.user_item_map.keys())
    
    def __len__(self):
        return len(self.users)
    
    def __getitem__(self, idx):
        user = self.users[idx]
        pos_items = self.user_item_map[user]
        
        # Seleccionar un ítem positivo aleatorio
        pos_item = random.choice(pos_items)
        
        # Seleccionar un ítem negativo aleatorio (no valorado por el usuario)
        neg_item = random.choice(self.all_items)
        while neg_item in pos_items:
            neg_item = random.choice(self.all_items)
        
        return torch.tensor(user, dtype=torch.long), \
               torch.tensor(pos_item, dtype=torch.long), \
               torch.tensor(neg_item, dtype=torch.long)

# %% [markdown]
# # ***NCF (Neural Collaborative Filtering) Recommender***

# %%
class NeuralCollaborativeFiltering(nn.Module):
    def __init__(self, n_users, n_movies, embedding_dim=50, hidden_dim=128):
        super(NeuralCollaborativeFiltering, self).__init__()
        
        # Embedding layers
        self.user_embedding = nn.Embedding(n_users, embedding_dim)
        self.movie_embedding = nn.Embedding(n_movies, embedding_dim)
        
        # MLP layers
        self.mlp = nn.Sequential(
            nn.Linear(embedding_dim * 2, hidden_dim),
            nn.ReLU(),
            nn.Linear(hidden_dim, 1)
        )
    
    def forward(self, user, item):
        user_embedded = self.user_embedding(user)
        item_embedded = self.movie_embedding(item)
        x = torch.cat([user_embedded, item_embedded], dim=1)
        return self.mlp(x).squeeze()
    
    def predict(self, user, item):
        return self.forward(user, item)

# %% [markdown]
# # **Funciones para la evaluación Top-K**

# %%
def get_user_positive_items(ratings_df):
    """Crea un diccionario con los ítems positivos para cada usuario"""
    user_pos_items = {}
    for user in ratings_df['userId'].unique():
        user_pos_items[user] = set(ratings_df[ratings_df['userId'] == user]['movieId'].values)
    return user_pos_items

def generate_recommendations(model, user_ids, all_item_ids, k=10):
    """Genera recomendaciones Top-K para una lista de usuarios"""
    model.eval()
    recommendations = {}
    
    with torch.no_grad():
        for user_id in user_ids:
            # Crear tensores para el usuario y todos los ítems
            user_tensor = torch.tensor([user_id] * len(all_item_ids), dtype=torch.long)
            item_tensor = torch.tensor(all_item_ids, dtype=torch.long)
            
            # Obtener predicciones
            scores = model.predict(user_tensor, item_tensor)
            
            # Ordenar y obtener los Top-K ítems
            _, top_indices = torch.topk(scores, k=k)
            recommended_items = item_tensor[top_indices].numpy()
            recommendations[user_id] = recommended_items
    
    return recommendations

def calculate_topk_metrics(model, test_df, train_df, user_pos_items, all_item_ids, k_values=[5, 10, 20]):
    """Calcula métricas Top-K para diferentes valores de K"""
    test_users = test_df['userId'].unique()
    metrics = {f'recall@{k}': [] for k in k_values}
    metrics.update({f'ndcg@{k}': [] for k in k_values})
    
    # Generar recomendaciones para todos los usuarios de test
    recommendations = generate_recommendations(model, test_users, all_item_ids, k=max(k_values))
    
    for user_id in test_users:
        # Ítems relevantes en test (consideramos relevantes rating >= 4)
        relevant_items = set(test_df[(test_df['userId'] == user_id) & (test_df['rating'] >= 4)]['movieId'].values)
        if not relevant_items:
            continue
            
        # Ítems ya vistos en train (para excluirlos)
        seen_items = user_pos_items.get(user_id, set())
        
        # Recomendaciones para este usuario (ya excluyen ítems vistos)
        recommended_items = recommendations[user_id]
        
        for k in k_values:
            # Tomar los primeros k ítems recomendados
            top_k = recommended_items[:k]
            
            # Calcular Recall@K
            hits = len(set(top_k) & relevant_items)
            recall = hits / len(relevant_items)
            metrics[f'recall@{k}'].append(recall)
            
            # Calcular NDCG@K
            dcg = 0.0
            for i, item in enumerate(top_k):
                if item in relevant_items:
                    dcg += 1.0 / np.log2(i + 2)  # +2 porque el ranking empieza en 1
            
            idcg = sum(1.0 / np.log2(i + 2) for i in range(min(len(relevant_items), k)))
            ndcg = dcg / idcg if idcg > 0 else 0.0
            metrics[f'ndcg@{k}'].append(ndcg)
    
    # Promediar las métricas
    avg_metrics = {k: np.mean(v) for k, v in metrics.items() if v}
    return avg_metrics

# %% [markdown]
# # **Función de Pérdida para Ranking (BPR Loss)**

# %%
class BPRLoss(nn.Module):
    def __init__(self):
        super(BPRLoss, self).__init__()
    
    def forward(self, pos_preds, neg_preds):
        """Bayesian Personalized Ranking Loss"""
        return -torch.log(torch.sigmoid(pos_preds - neg_preds)).mean()

# %% [markdown]
# # **Entrenamiento y Evaluación**

# %%
'''
def calculate_metrics(model, loader):
    model.eval()
    total_loss = 0
    total_squared_error = 0
    total_absolute_error = 0
    total_samples = 0
    
    with torch.no_grad():
        for user, movie, rating in loader:
            output = model(user, movie)
            loss = criterion(output, rating)
            total_loss += loss.item() * len(rating)
            
            # Calculate squared error and absolute error
            squared_error = (output - rating) ** 2
            absolute_error = torch.abs(output - rating)
            
            # Accumulate total errors
            total_squared_error += squared_error.sum().item()
            total_absolute_error += absolute_error.sum().item()
            total_samples += len(rating)
    
    # Compute metrics
    avg_loss = total_loss / total_samples
    rmse = np.sqrt(total_squared_error / total_samples)
    mae = total_absolute_error / total_samples
    
    return avg_loss, rmse, mae
'''

def train_model():
    # Inicializar trackers
    print("Inicializando trackers...")
    system_tracker = SystemMetricsTracker()
    emissions_tracker = EmissionsPerEpochTracker(result_path, "NCF")
    
    # Inicializar listas para métricas
    train_losses = []
    top_k_metrics = {f'recall@{k}': [] for k in config['top_k_values']}
    top_k_metrics.update({f'ndcg@{k}': [] for k in config['top_k_values']})
    
    # Preparar datos para evaluación Top-K
    user_pos_items = get_user_positive_items(train_df)
    all_item_ids = ratings_df['movieId'].unique()
    
    # Crear datasets y dataloaders
    train_dataset = BPRDataset(train_df)
    train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
    
    # Función de pérdida
    criterion = BPRLoss()
    optimizer = optim.Adam(model.parameters(), lr=config['learning_rate'])
    
    print(f"\nComenzando entrenamiento ({config['epochs']} épocas)...")
    for epoch in range(config['epochs']):
        # Iniciar seguimiento
        system_tracker.start_epoch(epoch)
        emissions_tracker.start_epoch(epoch)
        
        # Modo entrenamiento
        model.train()
        total_loss = 0
        total_samples = 0
        
        for user, pos_item, neg_item in train_loader:
            optimizer.zero_grad()
            
            # Forward pass
            pos_pred = model(user, pos_item)
            neg_pred = model(user, neg_item)
            
            # Calcular pérdida
            loss = criterion(pos_pred, neg_pred)
            
            # Backward pass
            loss.backward()
            optimizer.step()
            
            total_loss += loss.item() * len(user)
            total_samples += len(user)
        
        # Calcular pérdida promedio
        avg_train_loss = total_loss / total_samples
        train_losses.append(avg_train_loss)
        
        # Evaluar métricas Top-K
        epoch_metrics = calculate_topk_metrics(
            model, val_df, train_df, user_pos_items, all_item_ids, config['top_k_values']
        )
        
        # Guardar métricas (corregido el problema de sintaxis)
        for k in config['top_k_values']:
            top_k_metrics[f'recall@{k}'].append(epoch_metrics[f'recall@{k}'])
            top_k_metrics[f'ndcg@{k}'].append(epoch_metrics[f'ndcg@{k}'])
        
        # Actualizar trackers
        system_tracker.end_epoch(epoch, avg_train_loss)
        emissions_tracker.end_epoch(epoch, avg_train_loss)
        
        # Mostrar progreso
        if (epoch + 1) % config['display_step'] == 0:
            print(f"Epoch {epoch + 1}/{config['epochs']}, Loss: {avg_train_loss:.4f}")
            for k in config['top_k_values']:
                print(f"  Recall@{k}: {epoch_metrics[f'recall@{k}']:.4f}, NDCG@{k}: {epoch_metrics[f'ndcg@{k}']:.4f}")
    
    # Evaluación final
    print("\nEvaluando modelo en conjunto de prueba final...")
    system_tracker.start_epoch("test")
    
    # Calcular métricas finales en el conjunto de test
    final_metrics = calculate_topk_metrics(
        model, val_df, train_df, user_pos_items, all_item_ids, config['top_k_values']
    )
    
    # Finalizar trackers
    try:
        system_tracker.end_test(final_metrics[f'recall@{config["top_k_values"][0]}'])
    except Exception as e:
        print(f"Error al generar métricas finales con tracker: {e}")
    
    try:
        emissions_tracker.end_training(final_metrics[f'recall@{config["top_k_values"][0]}'])
    except Exception as e:
        print(f"Error al generar métricas de emisiones: {e}")
    
    # Guardar métricas
    timestamp = time.strftime("%Y%m%d-%H%M%S")
    metrics_df = pd.DataFrame({
        'epoch': list(range(config['epochs'])),
        'train_loss': train_losses,
        **top_k_metrics
    })
    
    metrics_file = f"{result_path}/model_metrics_{timestamp}.csv"
    metrics_df.to_csv(metrics_file, index=False)
    print(f"Métricas del modelo guardadas en: {metrics_file}")
    
    # Mostrar métricas finales
    print("\n" + "="*60)
    print("MÉTRICAS FINALES TOP-K")
    print("="*60)
    for k in config['top_k_values']:
        print(f"Recall@{k}: {final_metrics[f'recall@{k}']:.4f}")
        print(f"NDCG@{k}: {final_metrics[f'ndcg@{k}']:.4f}")
    print("="*60)
    
    return final_metrics

# Preparar los datos
print("\nPreparando los datasets...")

train_df, val_df = train_test_split(ratings_df, test_size=config['test_size'], random_state=config['random_state'])

# Crear datasets y dataloaders
train_dataset = BPRDataset(train_df)
val_dataset = BPRDataset(val_df)

train_loader = DataLoader(train_dataset, batch_size=config['batch_size'], shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=config['batch_size'], shuffle=False)

print(f"Datos preparados: {len(train_df)} muestras de entrenamiento, {len(val_df)} muestras de validación")

# Inicializar modelo
model = NeuralCollaborativeFiltering(n_users, n_movies, 
                                    embedding_dim=config['embedding_dim'], 
                                    hidden_dim=config['hidden_dim'])

# Entrenar modelo
final_metrics = train_model()

print("Entrenamiento completado exitosamente!")
# Out:
# Preparando los datasets...
# Datos preparados: 800167 muestras de entrenamiento, 200042 muestras de validación
# Inicializando trackers...
# Tracker principal iniciado correctamente
#
# Comenzando entrenamiento (50 épocas)...
#
# Epoch 0 Metrics:
#   Time: 35.85s
#   Memory: 738.46MB
#   CPU: 36.1%
#   Loss: 0.6942
# Epoch 0 - Emisiones: 0.00001918 kg, Acumulado: 0.00001918 kg, Loss: 0.6942
# Epoch 1/50, Loss: 0.6942
#   Recall@5: 0.0065, NDCG@5: 0.0249
#   Recall@10: 0.0102, NDCG@10: 0.0216
#   Recall@20: 0.0168, NDCG@20: 0.0211
#
# Epoch 1 Metrics:
#   Time: 35.29s
#   Memory: 788.66MB
#   CPU: 48.2%
#   Loss: 0.6801
# Epoch 1 - Emisiones: 0.00001882 kg, Acumulado: 0.00003800 kg, Loss: 0.6801
# Epoch 2/50, Loss: 0.6801
#   Recall@5: 0.0150, NDCG@5: 0.0434
#   Recall@10: 0.0220, NDCG@10: 0.0389
#   Recall@20: 0.0305, NDCG@20: 0.0370
#
# Epoch 2 Metrics:
#   Time: 34.55s
#   Memory: 790.21MB
#   CPU: 43.6%
#   Loss: 0.6708
# Epoch 2 - Emisiones: 0.00001841 kg, Acumulado: 0.00005641 kg, Loss: 0.6708
# Epoch 3/50, Loss: 0.6708
#   Recall@5: 0.0158, NDCG@5: 0.0487
#   Recall@10: 0.0240, NDCG@10: 0.0444
#   Recall@20: 0.0353, NDCG@20: 0.0435
#
# Epoch 3 Metrics:
#   Time: 34.00s
#   Memory: 791.04MB
#   CPU: 43.9%
#   Loss: 0.6524
# Epoch 3 - Emisiones: 0.00001807 kg, Acumulado: 0.00007448 kg, Loss: 0.6524
# Epoch 4/50, Loss: 0.6524
#   Recall@5: 0.0157, NDCG@5: 0.0485
#   Recall@10: 0.0244, NDCG@10: 0.0448
#   Recall@20: 0.0362, NDCG@20: 0.0443
#
# Epoch 4 Metrics:
#   Time: 33.72s
#   Memory: 791.26MB
#   CPU: 43.2%
#   Loss: 0.6473
# Epoch 4 - Emisiones: 0.00001791 kg, Acumulado: 0.00009239 kg, Loss: 0.6473
# Epoch 5/50, Loss: 0.6473
#   Recall@5: 0.0151, NDCG@5: 0.0456
#   Recall@10: 0.0237, NDCG@10: 0.0429
#   Recall@20: 0.0366, NDCG@20: 0.0436
#
# Epoch 5 Metrics:
#   Time: 33.07s
#   Memory: 791.23MB
#   CPU: 42.9%
#   Loss: 0.6334
# Epoch 5 - Emisiones: 0.00001748 kg, Acumulado: 0.00010987 kg, Loss: 0.6334
# Epoch 6/50, Loss: 0.6334
#   Recall@5: 0.0145, NDCG@5: 0.0467
#   Recall@10: 0.0232, NDCG@10: 0.0437
#   Recall@20: 0.0395, NDCG@20: 0.0462
#
# Epoch 6 Metrics:
#   Time: 35.03s
#   Memory: 791.22MB
#   CPU: 42.7%
#   Loss: 0.6219
# Epoch 6 - Emisiones: 0.00001872 kg, Acumulado: 0.00012859 kg, Loss: 0.6219
# Epoch 7/50, Loss: 0.6219
#   Recall@5: 0.0146, NDCG@5: 0.0477
#   Recall@10: 0.0233, NDCG@10: 0.0449
#   Recall@20: 0.0437, NDCG@20: 0.0492
#
# Epoch 7 Metrics:
#   Time: 34.53s
#   Memory: 791.90MB
#   CPU: 45.3%
#   Loss: 0.6076
# Epoch 7 - Emisiones: 0.00001830 kg, Acumulado: 0.00014689 kg, Loss: 0.6076
# Epoch 8/50, Loss: 0.6076
#   Recall@5: 0.0161, NDCG@5: 0.0513
#   Recall@10: 0.0278, NDCG@10: 0.0499
#   Recall@20: 0.0495, NDCG@20: 0.0541
#
# Epoch 8 Metrics:
#   Time: 34.00s
#   Memory: 791.99MB
#   CPU: 47.9%
#   Loss: 0.5960
# Epoch 8 - Emisiones: 0.00001805 kg, Acumulado: 0.00016494 kg, Loss: 0.5960
# Epoch 9/50, Loss: 0.5960
#   Recall@5: 0.0192, NDCG@5: 0.0584
#   Recall@10: 0.0318, NDCG@10: 0.0562
#   Recall@20: 0.0537, NDCG@20: 0.0594
#
# Epoch 9 Metrics:
#   Time: 33.57s
#   Memory: 792.09MB
#   CPU: 43.1%
#   Loss: 0.5944
# Epoch 9 - Emisiones: 0.00001781 kg, Acumulado: 0.00018275 kg, Loss: 0.5944
# Epoch 10/50, Loss: 0.5944
#   Recall@5: 0.0217, NDCG@5: 0.0646
#   Recall@10: 0.0352, NDCG@10: 0.0614
#   Recall@20: 0.0577, NDCG@20: 0.0642
#
# Epoch 10 Metrics:
#   Time: 34.65s
#   Memory: 792.23MB
#   CPU: 42.6%
#   Loss: 0.5802
# Epoch 10 - Emisiones: 0.00001841 kg, Acumulado: 0.00020116 kg, Loss: 0.5802
# Epoch 11/50, Loss: 0.5802
#   Recall@5: 0.0231, NDCG@5: 0.0679
#   Recall@10: 0.0375, NDCG@10: 0.0646
#   Recall@20: 0.0645, NDCG@20: 0.0695
#
# Epoch 11 Metrics:
#   Time: 33.41s
#   Memory: 792.19MB
#   CPU: 44.1%
#   Loss: 0.5477
# Epoch 11 - Emisiones: 0.00001769 kg, Acumulado: 0.00021885 kg, Loss: 0.5477
# Epoch 12/50, Loss: 0.5477
#   Recall@5: 0.0236, NDCG@5: 0.0672
#   Recall@10: 0.0390, NDCG@10: 0.0653
#   Recall@20: 0.0649, NDCG@20: 0.0694
#
# Epoch 12 Metrics:
#   Time: 33.22s
#   Memory: 792.18MB
#   CPU: 42.5%
#   Loss: 0.5403
# Epoch 12 - Emisiones: 0.00001758 kg, Acumulado: 0.00023643 kg, Loss: 0.5403
# Epoch 13/50, Loss: 0.5403
#   Recall@5: 0.0223, NDCG@5: 0.0624
#   Recall@10: 0.0407, NDCG@10: 0.0647
#   Recall@20: 0.0687, NDCG@20: 0.0708
#
# Epoch 13 Metrics:
#   Time: 34.62s
#   Memory: 792.24MB
#   CPU: 42.7%
#   Loss: 0.5350
# Epoch 13 - Emisiones: 0.00001846 kg, Acumulado: 0.00025489 kg, Loss: 0.5350
# Epoch 14/50, Loss: 0.5350
#   Recall@5: 0.0226, NDCG@5: 0.0643
#   Recall@10: 0.0416, NDCG@10: 0.0666
#   Recall@20: 0.0722, NDCG@20: 0.0737
#
# Epoch 14 Metrics:
#   Time: 33.82s
#   Memory: 792.24MB
#   CPU: 43.8%
#   Loss: 0.5179
# Epoch 14 - Emisiones: 0.00001796 kg, Acumulado: 0.00027285 kg, Loss: 0.5179
# Epoch 15/50, Loss: 0.5179
#   Recall@5: 0.0214, NDCG@5: 0.0634
#   Recall@10: 0.0426, NDCG@10: 0.0675
#   Recall@20: 0.0760, NDCG@20: 0.0763
#
# Epoch 15 Metrics:
#   Time: 33.45s
#   Memory: 779.29MB
#   CPU: 44.2%
#   Loss: 0.5102
# Epoch 15 - Emisiones: 0.00001773 kg, Acumulado: 0.00029058 kg, Loss: 0.5102
# Epoch 16/50, Loss: 0.5102
#   Recall@5: 0.0225, NDCG@5: 0.0670
#   Recall@10: 0.0424, NDCG@10: 0.0690
#   Recall@20: 0.0786, NDCG@20: 0.0792
#
# Epoch 16 Metrics:
#   Time: 32.32s
#   Memory: 780.65MB
#   CPU: 44.4%
#   Loss: 0.4983
# Epoch 16 - Emisiones: 0.00001702 kg, Acumulado: 0.00030760 kg, Loss: 0.4983
# Epoch 17/50, Loss: 0.4983
#   Recall@5: 0.0246, NDCG@5: 0.0712
#   Recall@10: 0.0450, NDCG@10: 0.0723
#   Recall@20: 0.0811, NDCG@20: 0.0815
#
# Epoch 17 Metrics:
#   Time: 32.34s
#   Memory: 780.80MB
#   CPU: 41.6%
#   Loss: 0.4793
# Epoch 17 - Emisiones: 0.00001703 kg, Acumulado: 0.00032463 kg, Loss: 0.4793
# Epoch 18/50, Loss: 0.4793
#   Recall@5: 0.0258, NDCG@5: 0.0725
#   Recall@10: 0.0477, NDCG@10: 0.0746
#   Recall@20: 0.0834, NDCG@20: 0.0831
#
# Epoch 18 Metrics:
#   Time: 32.28s
#   Memory: 782.09MB
#   CPU: 42.3%
#   Loss: 0.4764
# Epoch 18 - Emisiones: 0.00001699 kg, Acumulado: 0.00034162 kg, Loss: 0.4764
# Epoch 19/50, Loss: 0.4764
#   Recall@5: 0.0258, NDCG@5: 0.0724
#   Recall@10: 0.0497, NDCG@10: 0.0760
#   Recall@20: 0.0865, NDCG@20: 0.0846
#
# Epoch 19 Metrics:
#   Time: 32.43s
#   Memory: 782.18MB
#   CPU: 41.8%
#   Loss: 0.4670
# Epoch 19 - Emisiones: 0.00001708 kg, Acumulado: 0.00035870 kg, Loss: 0.4670
# Epoch 20/50, Loss: 0.4670
#   Recall@5: 0.0272, NDCG@5: 0.0761
#   Recall@10: 0.0512, NDCG@10: 0.0790
#   Recall@20: 0.0886, NDCG@20: 0.0874
#
# Epoch 20 Metrics:
#   Time: 32.86s
#   Memory: 782.18MB
#   CPU: 41.6%
#   Loss: 0.4549
# Epoch 20 - Emisiones: 0.00001736 kg, Acumulado: 0.00037606 kg, Loss: 0.4549
# Epoch 21/50, Loss: 0.4549
#   Recall@5: 0.0292, NDCG@5: 0.0815
#   Recall@10: 0.0518, NDCG@10: 0.0816
#   Recall@20: 0.0926, NDCG@20: 0.0916
#
# Epoch 21 Metrics:
#   Time: 32.59s
#   Memory: 782.35MB
#   CPU: 43.3%
#   Loss: 0.4405
# Epoch 21 - Emisiones: 0.00001719 kg, Acumulado: 0.00039325 kg, Loss: 0.4405
# Epoch 22/50, Loss: 0.4405
#   Recall@5: 0.0310, NDCG@5: 0.0840
#   Recall@10: 0.0535, NDCG@10: 0.0841
#   Recall@20: 0.0934, NDCG@20: 0.0930
#
# Epoch 22 Metrics:
#   Time: 32.70s
#   Memory: 782.55MB
#   CPU: 43.1%
#   Loss: 0.4375
# Epoch 22 - Emisiones: 0.00001727 kg, Acumulado: 0.00041052 kg, Loss: 0.4375
# Epoch 23/50, Loss: 0.4375
#   Recall@5: 0.0320, NDCG@5: 0.0858
#   Recall@10: 0.0545, NDCG@10: 0.0852
#   Recall@20: 0.0944, NDCG@20: 0.0939
#
# Epoch 23 Metrics:
#   Time: 32.45s
#   Memory: 782.81MB
#   CPU: 43.4%
#   Loss: 0.4275
# Epoch 23 - Emisiones: 0.00001709 kg, Acumulado: 0.00042761 kg, Loss: 0.4275
# Epoch 24/50, Loss: 0.4275
#   Recall@5: 0.0318, NDCG@5: 0.0845
#   Recall@10: 0.0534, NDCG@10: 0.0842
#   Recall@20: 0.0931, NDCG@20: 0.0929
#
# Epoch 24 Metrics:
#   Time: 32.57s
#   Memory: 782.83MB
#   CPU: 42.4%
#   Loss: 0.4211
# Epoch 24 - Emisiones: 0.00001718 kg, Acumulado: 0.00044479 kg, Loss: 0.4211
# Epoch 25/50, Loss: 0.4211
#   Recall@5: 0.0306, NDCG@5: 0.0835
#   Recall@10: 0.0545, NDCG@10: 0.0851
#   Recall@20: 0.0919, NDCG@20: 0.0927
#
# Epoch 25 Metrics:
#   Time: 32.18s
#   Memory: 782.85MB
#   CPU: 43.3%
#   Loss: 0.4090
# Epoch 25 - Emisiones: 0.00001694 kg, Acumulado: 0.00046173 kg, Loss: 0.4090
# Epoch 26/50, Loss: 0.4090
#   Recall@5: 0.0303, NDCG@5: 0.0834
#   Recall@10: 0.0539, NDCG@10: 0.0845
#   Recall@20: 0.0918, NDCG@20: 0.0923
#
# Epoch 26 Metrics:
#   Time: 35.12s
#   Memory: 782.96MB
#   CPU: 41.6%
#   Loss: 0.4212
# Epoch 26 - Emisiones: 0.00001878 kg, Acumulado: 0.00048051 kg, Loss: 0.4212
# Epoch 27/50, Loss: 0.4212
#   Recall@5: 0.0308, NDCG@5: 0.0838
#   Recall@10: 0.0531, NDCG@10: 0.0840
#   Recall@20: 0.0929, NDCG@20: 0.0929
#
# Epoch 27 Metrics:
#   Time: 34.96s
#   Memory: 782.99MB
#   CPU: 45.5%
#   Loss: 0.3982
# Epoch 27 - Emisiones: 0.00001865 kg, Acumulado: 0.00049916 kg, Loss: 0.3982
# Epoch 28/50, Loss: 0.3982
#   Recall@5: 0.0313, NDCG@5: 0.0844
#   Recall@10: 0.0519, NDCG@10: 0.0830
#   Recall@20: 0.0925, NDCG@20: 0.0923
#
# Epoch 28 Metrics:
#   Time: 36.32s
#   Memory: 782.99MB
#   CPU: 44.0%
#   Loss: 0.4000
# Epoch 28 - Emisiones: 0.00001951 kg, Acumulado: 0.00051867 kg, Loss: 0.4000
# Epoch 29/50, Loss: 0.4000
#   Recall@5: 0.0311, NDCG@5: 0.0813
#   Recall@10: 0.0529, NDCG@10: 0.0819
#   Recall@20: 0.0939, NDCG@20: 0.0918
#
# Epoch 29 Metrics:
#   Time: 33.59s
#   Memory: 782.99MB
#   CPU: 49.6%
#   Loss: 0.3980
# Epoch 29 - Emisiones: 0.00001782 kg, Acumulado: 0.00053648 kg, Loss: 0.3980
# Epoch 30/50, Loss: 0.3980
#   Recall@5: 0.0296, NDCG@5: 0.0806
#   Recall@10: 0.0518, NDCG@10: 0.0815
#   Recall@20: 0.0936, NDCG@20: 0.0920
#
# Epoch 30 Metrics:
#   Time: 33.33s
#   Memory: 783.05MB
#   CPU: 42.9%
#   Loss: 0.4022
# Epoch 30 - Emisiones: 0.00001765 kg, Acumulado: 0.00055413 kg, Loss: 0.4022
# Epoch 31/50, Loss: 0.4022
#   Recall@5: 0.0280, NDCG@5: 0.0777
#   Recall@10: 0.0504, NDCG@10: 0.0793
#   Recall@20: 0.0914, NDCG@20: 0.0900
#
# Epoch 31 Metrics:
#   Time: 35.01s
#   Memory: 783.05MB
#   CPU: 42.3%
#   Loss: 0.3811
# Epoch 31 - Emisiones: 0.00001868 kg, Acumulado: 0.00057281 kg, Loss: 0.3811
# Epoch 32/50, Loss: 0.3811
#   Recall@5: 0.0277, NDCG@5: 0.0769
#   Recall@10: 0.0503, NDCG@10: 0.0785
#   Recall@20: 0.0899, NDCG@20: 0.0884
#
# Epoch 32 Metrics:
#   Time: 33.43s
#   Memory: 783.12MB
#   CPU: 42.0%
#   Loss: 0.3783
# Epoch 32 - Emisiones: 0.00001772 kg, Acumulado: 0.00059052 kg, Loss: 0.3783
# Epoch 33/50, Loss: 0.3783
#   Recall@5: 0.0288, NDCG@5: 0.0783
#   Recall@10: 0.0517, NDCG@10: 0.0800
#   Recall@20: 0.0916, NDCG@20: 0.0897
#
# Epoch 33 Metrics:
#   Time: 33.94s
#   Memory: 783.12MB
#   CPU: 42.4%
#   Loss: 0.3940
# Epoch 33 - Emisiones: 0.00001803 kg, Acumulado: 0.00060855 kg, Loss: 0.3940
# Epoch 34/50, Loss: 0.3940
#   Recall@5: 0.0301, NDCG@5: 0.0802
#   Recall@10: 0.0547, NDCG@10: 0.0832
#   Recall@20: 0.0954, NDCG@20: 0.0929
#
# Epoch 34 Metrics:
#   Time: 34.03s
#   Memory: 783.12MB
#   CPU: 42.7%
#   Loss: 0.3832
# Epoch 34 - Emisiones: 0.00001807 kg, Acumulado: 0.00062662 kg, Loss: 0.3832
# Epoch 35/50, Loss: 0.3832
#   Recall@5: 0.0317, NDCG@5: 0.0852
#   Recall@10: 0.0568, NDCG@10: 0.0871
#   Recall@20: 0.0984, NDCG@20: 0.0964
#
# Epoch 35 Metrics:
#   Time: 33.46s
#   Memory: 783.12MB
#   CPU: 42.2%
#   Loss: 0.3795
# Epoch 35 - Emisiones: 0.00001772 kg, Acumulado: 0.00064435 kg, Loss: 0.3795
# Epoch 36/50, Loss: 0.3795
#   Recall@5: 0.0322, NDCG@5: 0.0872
#   Recall@10: 0.0567, NDCG@10: 0.0877
#   Recall@20: 0.1001, NDCG@20: 0.0974
#
# Epoch 36 Metrics:
#   Time: 34.07s
#   Memory: 783.17MB
#   CPU: 43.0%
#   Loss: 0.3845
# Epoch 36 - Emisiones: 0.00001810 kg, Acumulado: 0.00066245 kg, Loss: 0.3845
# Epoch 37/50, Loss: 0.3845
#   Recall@5: 0.0326, NDCG@5: 0.0879
#   Recall@10: 0.0563, NDCG@10: 0.0880
#   Recall@20: 0.1005, NDCG@20: 0.0981
#
# Epoch 37 Metrics:
#   Time: 33.22s
#   Memory: 783.18MB
#   CPU: 42.6%
#   Loss: 0.3713
# Epoch 37 - Emisiones: 0.00001761 kg, Acumulado: 0.00068006 kg, Loss: 0.3713
# Epoch 38/50, Loss: 0.3713
#   Recall@5: 0.0319, NDCG@5: 0.0864
#   Recall@10: 0.0562, NDCG@10: 0.0875
#   Recall@20: 0.0991, NDCG@20: 0.0971
#
# Epoch 38 Metrics:
#   Time: 34.02s
#   Memory: 783.07MB
#   CPU: 42.5%
#   Loss: 0.3709
# Epoch 38 - Emisiones: 0.00001807 kg, Acumulado: 0.00069813 kg, Loss: 0.3709
# Epoch 39/50, Loss: 0.3709
#   Recall@5: 0.0318, NDCG@5: 0.0858
#   Recall@10: 0.0555, NDCG@10: 0.0863
#   Recall@20: 0.0973, NDCG@20: 0.0957
#
# Epoch 39 Metrics:
#   Time: 33.05s
#   Memory: 783.10MB
#   CPU: 43.1%
#   Loss: 0.3631
# Epoch 39 - Emisiones: 0.00001748 kg, Acumulado: 0.00071561 kg, Loss: 0.3631
# Epoch 40/50, Loss: 0.3631
#   Recall@5: 0.0322, NDCG@5: 0.0862
#   Recall@10: 0.0544, NDCG@10: 0.0858
#   Recall@20: 0.0967, NDCG@20: 0.0958
#
# Epoch 40 Metrics:
#   Time: 33.22s
#   Memory: 783.18MB
#   CPU: 42.6%
#   Loss: 0.3611
# Epoch 40 - Emisiones: 0.00001757 kg, Acumulado: 0.00073318 kg, Loss: 0.3611
# Epoch 41/50, Loss: 0.3611
#   Recall@5: 0.0315, NDCG@5: 0.0863
#   Recall@10: 0.0544, NDCG@10: 0.0867
#   Recall@20: 0.0975, NDCG@20: 0.0968
#
# Epoch 41 Metrics:
#   Time: 32.84s
#   Memory: 783.18MB
#   CPU: 42.3%
#   Loss: 0.3629
# Epoch 41 - Emisiones: 0.00001734 kg, Acumulado: 0.00075052 kg, Loss: 0.3629
# Epoch 42/50, Loss: 0.3629
#   Recall@5: 0.0322, NDCG@5: 0.0870
#   Recall@10: 0.0552, NDCG@10: 0.0876
#   Recall@20: 0.0993, NDCG@20: 0.0981
#
# Epoch 42 Metrics:
#   Time: 33.24s
#   Memory: 783.18MB
#   CPU: 41.9%
#   Loss: 0.3571
# Epoch 42 - Emisiones: 0.00001759 kg, Acumulado: 0.00076811 kg, Loss: 0.3571
# Epoch 43/50, Loss: 0.3571
#   Recall@5: 0.0322, NDCG@5: 0.0863
#   Recall@10: 0.0562, NDCG@10: 0.0879
#   Recall@20: 0.1009, NDCG@20: 0.0986
#
# Epoch 43 Metrics:
#   Time: 61.15s
#   Memory: 783.18MB
#   CPU: 43.9%
#   Loss: 0.3620
# Epoch 43 - Emisiones: 0.00003483 kg, Acumulado: 0.00080293 kg, Loss: 0.3620
# Epoch 44/50, Loss: 0.3620
#   Recall@5: 0.0321, NDCG@5: 0.0862
#   Recall@10: 0.0565, NDCG@10: 0.0879
#   Recall@20: 0.1013, NDCG@20: 0.0991
#
# Epoch 44 Metrics:
#   Time: 33.09s
#   Memory: 783.31MB
#   CPU: 77.0%
#   Loss: 0.3497
# Epoch 44 - Emisiones: 0.00001747 kg, Acumulado: 0.00082040 kg, Loss: 0.3497
# Epoch 45/50, Loss: 0.3497
#   Recall@5: 0.0322, NDCG@5: 0.0850
#   Recall@10: 0.0568, NDCG@10: 0.0871
#   Recall@20: 0.1010, NDCG@20: 0.0981
#
# Epoch 45 Metrics:
#   Time: 35.83s
#   Memory: 783.31MB
#   CPU: 44.1%
#   Loss: 0.3501
# Epoch 45 - Emisiones: 0.00001921 kg, Acumulado: 0.00083961 kg, Loss: 0.3501
# Epoch 46/50, Loss: 0.3501
#   Recall@5: 0.0321, NDCG@5: 0.0840
#   Recall@10: 0.0563, NDCG@10: 0.0857
#   Recall@20: 0.1003, NDCG@20: 0.0970
#
# Epoch 46 Metrics:
#   Time: 33.49s
#   Memory: 783.92MB
#   CPU: 50.5%
#   Loss: 0.3668
# Epoch 46 - Emisiones: 0.00001775 kg, Acumulado: 0.00085736 kg, Loss: 0.3668
# Epoch 47/50, Loss: 0.3668
#   Recall@5: 0.0315, NDCG@5: 0.0849
#   Recall@10: 0.0554, NDCG@10: 0.0852
#   Recall@20: 0.1001, NDCG@20: 0.0970
#
# Epoch 47 Metrics:
#   Time: 33.10s
#   Memory: 784.00MB
#   CPU: 45.6%
#   Loss: 0.3608
# Epoch 47 - Emisiones: 0.00001751 kg, Acumulado: 0.00087488 kg, Loss: 0.3608
# Epoch 48/50, Loss: 0.3608
#   Recall@5: 0.0321, NDCG@5: 0.0856
#   Recall@10: 0.0552, NDCG@10: 0.0854
#   Recall@20: 0.0999, NDCG@20: 0.0969
#
# Epoch 48 Metrics:
#   Time: 33.19s
#   Memory: 784.01MB
#   CPU: 43.9%
#   Loss: 0.3558
# Epoch 48 - Emisiones: 0.00001758 kg, Acumulado: 0.00089245 kg, Loss: 0.3558
# Epoch 49/50, Loss: 0.3558
#   Recall@5: 0.0305, NDCG@5: 0.0834
#   Recall@10: 0.0556, NDCG@10: 0.0846
#   Recall@20: 0.0998, NDCG@20: 0.0961
#
# Epoch 49 Metrics:
#   Time: 33.48s
#   Memory: 784.02MB
#   CPU: 43.6%
#   Loss: 0.3507
# Epoch 49 - Emisiones: 0.00001774 kg, Acumulado: 0.00091019 kg, Loss: 0.3507
# Epoch 50/50, Loss: 0.3507
#   Recall@5: 0.0303, NDCG@5: 0.0816
#   Recall@10: 0.0541, NDCG@10: 0.0831
#   Recall@20: 0.0986, NDCG@20: 0.0945
#
# Evaluando modelo en conjunto de prueba final...
#
# === Final Training Metrics ===
# Epoch 0: Time=35.85s, Memory=738.46MB, CPU=36.1%, Loss=0.6942
# Epoch 1: Time=35.29s, Memory=788.66MB, CPU=48.2%, Loss=0.6801
# Epoch 2: Time=34.55s, Memory=790.21MB, CPU=43.6%, Loss=0.6708
# Epoch 3: Time=34.00s, Memory=791.04MB, CPU=43.9%, Loss=0.6524
# Epoch 4: Time=33.72s, Memory=791.26MB, CPU=43.2%, Loss=0.6473
# Epoch 5: Time=33.07s, Memory=791.23MB, CPU=42.9%, Loss=0.6334
# Epoch 6: Time=35.03s, Memory=791.22MB, CPU=42.7%, Loss=0.6219
# Epoch 7: Time=34.53s, Memory=791.90MB, CPU=45.3%, Loss=0.6076
# Epoch 8: Time=34.00s, Memory=791.99MB, CPU=47.9%, Loss=0.5960
# Epoch 9: Time=33.57s, Memory=792.09MB, CPU=43.1%, Loss=0.5944
# Epoch 10: Time=34.65s, Memory=792.23MB, CPU=42.6%, Loss=0.5802
# Epoch 11: Time=33.41s, Memory=792.19MB, CPU=44.1%, Loss=0.5477
# Epoch 12: Time=33.22s, Memory=792.18MB, CPU=42.5%, Loss=0.5403
# Epoch 13: Time=34.62s, Memory=792.24MB, CPU=42.7%, Loss=0.5350
# Epoch 14: Time=33.82s, Memory=792.24MB, CPU=43.8%, Loss=0.5179
# Epoch 15: Time=33.45s, Memory=779.29MB, CPU=44.2%, Loss=0.5102
# Epoch 16: Time=32.32s, Memory=780.65MB, CPU=44.4%, Loss=0.4983
# Epoch 17: Time=32.34s, Memory=780.80MB, CPU=41.6%, Loss=0.4793
# Epoch 18: Time=32.28s, Memory=782.09MB, CPU=42.3%, Loss=0.4764
# Epoch 19: Time=32.43s, Memory=782.18MB, CPU=41.8%, Loss=0.4670
# Epoch 20: Time=32.86s, Memory=782.18MB, CPU=41.6%, Loss=0.4549
# Epoch 21: Time=32.59s, Memory=782.35MB, CPU=43.3%, Loss=0.4405
# Epoch 22: Time=32.70s, Memory=782.55MB, CPU=43.1%, Loss=0.4375
# Epoch 23: Time=32.45s, Memory=782.81MB, CPU=43.4%, Loss=0.4275
# Epoch 24: Time=32.57s, Memory=782.83MB, CPU=42.4%, Loss=0.4211
# Epoch 25: Time=32.18s, Memory=782.85MB, CPU=43.3%, Loss=0.4090
# Epoch 26: Time=35.12s, Memory=782.96MB, CPU=41.6%, Loss=0.4212
# Epoch 27: Time=34.96s, Memory=782.99MB, CPU=45.5%, Loss=0.3982
# Epoch 28: Time=36.32s, Memory=782.99MB, CPU=44.0%, Loss=0.4000
# Epoch 29: Time=33.59s, Memory=782.99MB, CPU=49.6%, Loss=0.3980
# Epoch 30: Time=33.33s, Memory=783.05MB, CPU=42.9%, Loss=0.4022
# Epoch 31: Time=35.01s, Memory=783.05MB, CPU=42.3%, Loss=0.3811
# Epoch 32: Time=33.43s, Memory=783.12MB, CPU=42.0%, Loss=0.3783
# Epoch 33: Time=33.94s, Memory=783.12MB, CPU=42.4%, Loss=0.3940
# Epoch 34: Time=34.03s, Memory=783.12MB, CPU=42.7%, Loss=0.3832
# Epoch 35: Time=33.46s, Memory=783.12MB, CPU=42.2%, Loss=0.3795
# Epoch 36: Time=34.07s, Memory=783.17MB, CPU=43.0%, Loss=0.3845
# Epoch 37: Time=33.22s, Memory=783.18MB, CPU=42.6%, Loss=0.3713
# Epoch 38: Time=34.02s, Memory=783.07MB, CPU=42.5%, Loss=0.3709
# Epoch 39: Time=33.05s, Memory=783.10MB, CPU=43.1%, Loss=0.3631
# Epoch 40: Time=33.22s, Memory=783.18MB, CPU=42.6%, Loss=0.3611
# Epoch 41: Time=32.84s, Memory=783.18MB, CPU=42.3%, Loss=0.3629
# Epoch 42: Time=33.24s, Memory=783.18MB, CPU=41.9%, Loss=0.3571
# Epoch 43: Time=61.15s, Memory=783.18MB, CPU=43.9%, Loss=0.3620
# Epoch 44: Time=33.09s, Memory=783.31MB, CPU=77.0%, Loss=0.3497
# Epoch 45: Time=35.83s, Memory=783.31MB, CPU=44.1%, Loss=0.3501
# Epoch 46: Time=33.49s, Memory=783.92MB, CPU=50.5%, Loss=0.3668
# Epoch 47: Time=33.10s, Memory=784.00MB, CPU=45.6%, Loss=0.3608
# Epoch 48: Time=33.19s, Memory=784.01MB, CPU=43.9%, Loss=0.3558
# Epoch 49: Time=33.48s, Memory=784.02MB, CPU=43.6%, Loss=0.3507
#
# === Final Test Metrics ===
# Total Time: 1797.40s (Test: 28.10s)
# Final Memory: 784.02MB
# Final CPU: 49.2%
# Test RMSE: 0.0303
#
# Total CO2 Emissions: 0.001108 kg
# Métricas de emisiones guardadas en: results/emissions_reports/emissions_metrics_NCF_20250430-171607.csv
# Gráfico guardado en: results/emissions_plots/cumulative_emissions_vs_rmse_NCF_20250430-171607.png
# Gráfico guardado en: results/emissions_plots/metrics_by_epoch_NCF_20250430-171607.png
# Gráfico guardado en: results/emissions_plots/cumulative_emissions_performance_scatter_NCF_20250430-171607.png
# Métricas del modelo guardadas en: results/model_metrics_20250430-171609.csv
#
# ============================================================
# MÉTRICAS FINALES TOP-K
# ============================================================
# Recall@5: 0.0303
# NDCG@5: 0.0816
# Recall@10: 0.0541
# NDCG@10: 0.0831
# Recall@20: 0.0986
# NDCG@20: 0.0945
# ============================================================
# Entrenamiento completado exitosamente!
